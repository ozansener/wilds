# %%
import glob
import numpy as np
import matplotlib.pyplot as plt

import csv
import os
import re

# %%
# %matplotlib inline

# %%
def read_to_dict(file_name):
    res_dict = {}
    keym = {}
    with open(file_name, newline='') as csvfile:
        csv_reader = csv.reader(csvfile, delimiter=',')
        for i, row in enumerate(csv_reader):
            if i == 0:
                for j, rr in enumerate(row):
                    res_dict[rr] = []
                    keym[j] = rr
            else:
                for j, rr in enumerate(row):
                    if j not in keym:
                        print('error')
                        break
                    res_dict[keym[j]].append(float(rr))
    return res_dict

# %%
def early_stop(result_dict, key1, key2, max_ep):
    if max_ep is None:
        best_ep_0 = np.argmax(np.array(result_dict[key1]))
        best_ep_1 = np.argmax(np.array(result_dict[key2]))
    else:
        best_ep_0 = np.argmax(np.array(result_dict[key1][0:max_ep]))
        best_ep_1 = np.argmax(np.array(result_dict[key2][0:max_ep]))
    return best_ep_0, best_ep_1

# %%
def collect_results(entries, res_keys, which, max_ep):
    map_k = {0:"test", 1:"val", 2:"id_test", 3: "train"}
    res = {}
    for i in range(2):
        res[i] = {"test":{}, "val":{}, "id_test":{}, "train":{}}
        for dic in ["test", "val", "id_test", "train"]:
            for res_k in res_keys:
                res[i][dic][res_k] = []
    for entry in entries:
        e1,e2 = early_stop(entries[entry][which],res_keys[0], res_keys[1], max_ep)
        for i, e_v in enumerate([e1, e2]):
            for res_k in res_keys:
                for j_id in range(4):
                    if entries[entry][j_id] is None:
                        continue
                    if e_v >= len(entries[entry][j_id][res_k]):
                        print("Error", res_k, len(entries[entry][j_id][res_k]), map_k[j_id])
                        res[i][map_k[j_id]][res_k].append(entries[entry][j_id][res_k][-1])
                    else:
                        res[i][map_k[j_id]][res_k].append(entries[entry][j_id][res_k][e_v])

    return res
def print_row(row, res_keys):
    final_str = ""
    for res_k in res_keys:
        final_str += " {:04.2f}".format(100*np.mean(row[res_k]))
        final_str += " {:04.2f}".format(100*np.std(row[res_k]))
    return final_str

# %%
def parse_config(log_di, my_keys):
    config = open(log_di+'log.txt').read().split('\n')
    dat_conf = {}
    for ll in config:
        if 'Epoch [0]' in ll:
            break
        if 'Dataset kwargs' in ll and '{}' not in ll:
            dat_conf[ll.split(':')[0]] = ll.split(':')[2]
        elif ll.split(':')[0] in my_keys:
            dat_conf[ll.split(':')[0]] = ll.split(':')[1]
    return dat_conf

def parse_config_orig(log_di, my_keys):
    config = open(log_di+'log.txt').read().split('\n')
    dat_conf = {}
    for ll in config:
        if 'Epoch [0]' in ll:
            break
        if ll.split(':')[0] in my_keys:
            dat_conf[ll.split(':')[0]] = ll.split(':')[1]
    return dat_conf

# %%
np.exp(np.linspace(np.log(0.0001),np.log(10),7))
# Out:
# array([1.00000000e-04, 6.81292069e-04, 4.64158883e-03, 3.16227766e-02,
#        2.15443469e-01, 1.46779927e+00, 1.00000000e+01])

# %% [markdown]
# # iWildCam

# %%
log_dicts = sorted(glob.glob('./iWildCamResults/logs_iwild_f*/'), key= lambda x:int(x.split('_')[-1].split('/')[0]))

# %%
my_keys = ['Dataset', 'Algorithm', 'Uniform over groups', 'Distinct groups', 'N groups per batch']
my_keys += ['Batch size', 'Rd type', 'Warm start epoch', 'Control only direction', 'Only inconsistent']
my_keys += ['Without sampling', 'Lr', 'Weight decay', 'Seed']

exps = {}
for log_di in log_dicts:
    dat_conf = parse_config_orig(log_di, my_keys)
    if not dat_conf['Dataset'] == ' iwildcam':
        continue
    exp_name = "{}_{}_{}".format(dat_conf['Warm start epoch'], dat_conf['Rd type'], dat_conf['Lr'])
    if exp_name not in exps:
        exps[exp_name] = {}
    exps[exp_name][dat_conf['Seed']] = (read_to_dict(log_di+'test_eval.csv'), 
                                        read_to_dict(log_di+'val_eval.csv'), 
                                        read_to_dict(log_di+'id_test_eval.csv'),
                                        read_to_dict(log_di+'train_eval.csv'))
    if '3e-05' not in exp_name:
        continue
    if '2_' not in exp_name or '-1_ ' in exp_name:
        continue
    print(log_di, exp_name)
# Out:
# ./iWildCamResults/logs_iwild_final_36/  2_ 0_ 3e-05
# ./iWildCamResults/logs_iwild_final_37/  2_ 0_ 3e-05
# ./iWildCamResults/logs_iwild_final_38/  2_ 0_ 3e-05
# ./iWildCamResults/logs_iwild_final_39/  2_ 1_ 3e-05
# ./iWildCamResults/logs_iwild_final_40/  2_ 1_ 3e-05
# ./iWildCamResults/logs_iwild_final_41/  2_ 1_ 3e-05
# ./iWildCamResults/logs_iwild_final_42/  2_ 2_ 3e-05
# ./iWildCamResults/logs_iwild_final_43/  2_ 2_ 3e-05
# ./iWildCamResults/logs_iwild_final_44/  2_ 2_ 3e-05
# ./iWildCamResults/logs_iwild_final_45/  2_ 3_ 3e-05
# ./iWildCamResults/logs_iwild_final_46/  2_ 3_ 3e-05
# ./iWildCamResults/logs_iwild_final_47/  2_ 3_ 3e-05

# %%
for exp_id in exps:
    if '3e-05' not in exp_id:
        continue
    #if '2_' not in exp_id or '-1_ ' in exp_id:
    #    continue
    resO = collect_results(exps[exp_id], ('acc_avg', 'F1-macro_all'),2 , None)
    print(exp_id)

    for alg in resO:
        res_test_str = "ES_{} ".format(alg) +print_row(resO[alg]['test'], ('acc_avg', 'F1-macro_all'))
        res_id_t_str = "ES_{} ".format(alg) +print_row(resO[alg]['id_test'], ('acc_avg', 'F1-macro_all'))
        res_train_str = "ES_{} ".format(alg) +print_row(resO[alg]['train'], ('acc_avg', 'F1-macro_all'))

        print("Te\t", res_test_str)
        print("ID \t", res_id_t_str)
        #print("Tr \t", res_train_str)
    print('\n')
# Out:
#  -1_ 0_ 3e-05
# Te	 ES_0  69.74 3.41 29.77 2.79
# ID 	 ES_0  74.49 0.42 44.67 0.48
# Te	 ES_1  71.43 3.24 29.14 3.14
# ID 	 ES_1  74.16 0.65 45.00 0.65
#
#
#  -1_ 1_ 3e-05
# Te	 ES_0  63.94 1.80 22.96 1.18
# ID 	 ES_0  71.90 1.45 42.63 1.28
# Te	 ES_1  64.01 1.68 24.52 2.24
# ID 	 ES_1  71.33 0.95 44.65 1.40
#
#
#  -1_ 2_ 3e-05
# Te	 ES_0  67.54 0.75 26.13 1.85
# ID 	 ES_0  72.42 0.31 38.64 1.48
# Te	 ES_1  66.97 1.22 26.69 1.71
# ID 	 ES_1  71.34 1.40 40.26 0.40
#
#
#  -1_ 3_ 3e-05
# Te	 ES_0  69.44 1.43 28.45 0.83
# ID 	 ES_0  74.12 0.31 46.55 3.21
# Te	 ES_1  68.28 1.31 27.99 1.26
# ID 	 ES_1  73.55 0.54 47.41 2.61
#
#
#  2_ 0_ 3e-05
# Te	 ES_0  73.81 2.87 33.85 1.42
# ID 	 ES_0  76.88 0.53 48.18 2.24
# Te	 ES_1  73.26 2.60 31.32 1.88
# ID 	 ES_1  75.01 1.70 48.92 1.57
#
#
#  2_ 1_ 3e-05
# Te	 ES_0  76.08 0.81 34.31 0.91
# ID 	 ES_0  76.54 0.62 47.29 3.33
# Te	 ES_1  72.65 4.48 32.52 3.19
# ID 	 ES_1  76.11 1.08 48.73 1.68
#
#
#  2_ 2_ 3e-05
# Te	 ES_0  76.00 0.58 34.46 1.00
# ID 	 ES_0  76.73 0.49 49.04 1.49
# Te	 ES_1  75.59 0.74 34.36 0.87
# ID 	 ES_1  76.69 0.53 49.11 1.43
#
#
#  2_ 3_ 3e-05
# Te	 ES_0  75.51 0.79 34.76 0.72
# ID 	 ES_0  76.75 0.51 48.58 1.82
# Te	 ES_1  73.58 2.52 30.42 2.44
# ID 	 ES_1  75.35 1.67 49.51 1.22

# %% [markdown]
# # Py150

# %%
log_dicts = sorted(glob.glob('./py150Results/rd_p_all_seeds*/'), key= lambda x:int(x.split('_')[-1].split('/')[0]))

# %%
my_keys = ['Dataset', 'Algorithm', 'Uniform over groups', 'Distinct groups', 'N groups per batch']
my_keys += ['Batch size', 'Rd type', 'Warm start epoch', 'Control only direction', 'Only inconsistent']
my_keys += ['Without sampling', 'Lr', 'Weight decay', 'Seed']

# %%
exps = {}
for log_di in log_dicts:
    dat_conf = parse_config_orig(log_di, my_keys)
    if not dat_conf['Dataset'] == ' py150':
        continue
    print(log_di, dat_conf['Lr'])
    exp_name = "{}_{}_{}_{}_{}".format(dat_conf['Warm start epoch'], dat_conf['Rd type'], 
                                 dat_conf['Lr'], dat_conf['N groups per batch'],
                                 dat_conf['Batch size'])
    if exp_name not in exps:
        exps[exp_name] = {}
    exps[exp_name][dat_conf['Seed']] = (read_to_dict(log_di+'test_eval.csv'), 
                                        read_to_dict(log_di+'val_eval.csv'), 
                                        read_to_dict(log_di+'id_test_eval.csv'),
                                        read_to_dict(log_di+'train_eval.csv'),
                                        log_di)
# Out:
# ./py150Results/rd_p_all_seeds_0/  1e-05
# ./py150Results/rd_p_all_seeds_1/  1e-05
# ./py150Results/rd_p_all_seeds_2/  1e-05
# ./py150Results/rd_p_all_seeds_3/  1e-05
# ./py150Results/rd_p_all_seeds_4/  1e-05
# ./py150Results/rd_p_all_seeds_5/  1e-05
# ./py150Results/rd_p_all_seeds_6/  1e-05
# ./py150Results/rd_p_all_seeds_7/  1e-05
# ./py150Results/rd_p_all_seeds_8/  1e-05
# ./py150Results/rd_p_all_seeds_9/  8e-05
# ./py150Results/rd_p_all_seeds_10/  8e-05
# ./py150Results/rd_p_all_seeds_11/  8e-05
# ./py150Results/rd_p_all_seeds_12/  8e-05
# ./py150Results/rd_p_all_seeds_13/  8e-05
# ./py150Results/rd_p_all_seeds_14/  8e-05
# ./py150Results/rd_p_all_seeds_15/  8e-05
# ./py150Results/rd_p_all_seeds_16/  8e-05
# ./py150Results/rd_p_all_seeds_17/  8e-05
# ./py150Results/rd_p_all_seeds_18/  1e-05
# ./py150Results/rd_p_all_seeds_19/  1e-05
# ./py150Results/rd_p_all_seeds_20/  1e-05
# ./py150Results/rd_p_all_seeds_21/  1e-05
# ./py150Results/rd_p_all_seeds_22/  1e-05
# ./py150Results/rd_p_all_seeds_23/  1e-05
# ./py150Results/rd_p_all_seeds_24/  1e-05
# ./py150Results/rd_p_all_seeds_25/  1e-05
# ./py150Results/rd_p_all_seeds_26/  1e-05
# ./py150Results/rd_p_all_seeds_27/  8e-05
# ./py150Results/rd_p_all_seeds_28/  8e-05
# ./py150Results/rd_p_all_seeds_29/  8e-05
# ./py150Results/rd_p_all_seeds_30/  8e-05
# ./py150Results/rd_p_all_seeds_31/  8e-05
# ./py150Results/rd_p_all_seeds_32/  8e-05
# ./py150Results/rd_p_all_seeds_33/  8e-05
# ./py150Results/rd_p_all_seeds_34/  8e-05
# ./py150Results/rd_p_all_seeds_35/  8e-05

# %%
for exp_id in exps:
    print(exp_id)
    #if not ('3_ 0_ 1e-05_ 2_ 6' in exp_id or '3_ 1_ 1e-05_ 2_ 6' in exp_id):
    #    continue
    for kk in exps[exp_id]:
        print(np.max(exps[exp_id][kk][0]['epoch']))
        print(exps[exp_id][kk][4])
    resO = collect_results(exps[exp_id], ('Acc (Class-Method)', 'Acc (Overall)'),0, None)

    for alg in resO:
        res_test_str = "ES_{} ".format(alg) +print_row(resO[alg]['test'], ('Acc (Class-Method)', 'Acc (Overall)'))
        res_id_t_str = "ES_{} ".format(alg) +print_row(resO[alg]['id_test'], ('Acc (Class-Method)', 'Acc (Overall)'))
        res_train_str = "ES_{} ".format(alg) +print_row(resO[alg]['train'], ('Acc (Class-Method)', 'Acc (Overall)'))

        print("Te\t", res_test_str)
        print("ID \t", res_id_t_str)
        #print("Tr \t", res_train_str)
    print('\n')
# Out:
#  -1_ 0_ 1e-05_ 2_ 6
# 11.0
# ./py150Results/rd_p_all_seeds_0/
# 11.0
# ./py150Results/rd_p_all_seeds_1/
# 5.0
# ./py150Results/rd_p_all_seeds_2/
# Te	 ES_0  66.38 0.11 68.14 0.04
# ID 	 ES_0  68.58 0.48 69.43 0.25
# Te	 ES_1  66.25 0.11 68.18 0.01
# ID 	 ES_1  68.48 0.17 69.49 0.11
#
#
#  -1_ 1_ 1e-05_ 2_ 6
# 12.0
# ./py150Results/rd_p_all_seeds_3/
# 11.0
# ./py150Results/rd_p_all_seeds_4/
# 5.0
# ./py150Results/rd_p_all_seeds_5/
# Te	 ES_0  66.44 0.09 68.12 0.04
# ID 	 ES_0  69.33 0.81 69.91 0.46
# Te	 ES_1  66.21 0.09 68.18 0.02
# ID 	 ES_1  68.89 0.52 69.87 0.39
#
#
#  -1_ 3_ 1e-05_ 2_ 6
# 11.0
# ./py150Results/rd_p_all_seeds_6/
# 9.0
# ./py150Results/rd_p_all_seeds_7/
# 5.0
# ./py150Results/rd_p_all_seeds_8/
# Te	 ES_0  66.36 0.09 68.13 0.05
# ID 	 ES_0  68.83 0.24 69.65 0.08
# Te	 ES_1  66.31 0.04 68.16 0.02
# ID 	 ES_1  68.64 0.19 69.57 0.12
#
#
#  -1_ 0_ 8e-05_ 2_ 6
# 3.0
# ./py150Results/rd_p_all_seeds_9/
# 7.0
# ./py150Results/rd_p_all_seeds_10/
# 3.0
# ./py150Results/rd_p_all_seeds_11/
# Te	 ES_0  64.34 0.34 66.55 0.07
# ID 	 ES_0  68.18 0.24 69.10 0.18
# Te	 ES_1  64.10 0.50 66.62 0.04
# ID 	 ES_1  68.45 0.47 69.26 0.33
#
#
#  -1_ 1_ 8e-05_ 2_ 6
# 7.0
# ./py150Results/rd_p_all_seeds_12/
# 5.0
# ./py150Results/rd_p_all_seeds_13/
# 3.0
# ./py150Results/rd_p_all_seeds_14/
# Te	 ES_0  63.92 0.11 66.41 0.01
# ID 	 ES_0  67.96 0.19 68.83 0.03
# Te	 ES_1  63.83 0.10 66.44 0.04
# ID 	 ES_1  68.16 0.48 69.09 0.39
#
#
#  -1_ 3_ 8e-05_ 2_ 6
# 6.0
# ./py150Results/rd_p_all_seeds_15/
# 6.0
# ./py150Results/rd_p_all_seeds_16/
# 4.0
# ./py150Results/rd_p_all_seeds_17/
# Te	 ES_0  64.14 0.08 66.49 0.07
# ID 	 ES_0  68.40 0.31 69.08 0.18
# Te	 ES_1  63.93 0.17 66.60 0.02
# ID 	 ES_1  67.52 1.41 68.81 0.80
#
#
#  3_ 0_ 1e-05_ 2_ 6
# 14.0
# ./py150Results/rd_p_all_seeds_18/
# 14.0
# ./py150Results/rd_p_all_seeds_19/
# 8.0
# ./py150Results/rd_p_all_seeds_20/
# Te	 ES_0  66.65 0.14 68.22 0.02
# ID 	 ES_0  69.32 1.03 69.81 0.55
# Te	 ES_1  66.33 0.10 68.25 0.01
# ID 	 ES_1  68.87 0.79 69.85 0.53
#
#
#  3_ 1_ 1e-05_ 2_ 6
# 14.0
# ./py150Results/rd_p_all_seeds_21/
# 14.0
# ./py150Results/rd_p_all_seeds_22/
# 8.0
# ./py150Results/rd_p_all_seeds_23/
# Te	 ES_0  66.67 0.14 68.23 0.02
# ID 	 ES_0  69.33 1.05 69.83 0.57
# Te	 ES_1  66.39 0.08 68.26 0.01
# ID 	 ES_1  69.34 1.02 70.15 0.68
#
#
#  3_ 3_ 1e-05_ 2_ 6
# 14.0
# ./py150Results/rd_p_all_seeds_24/
# 14.0
# ./py150Results/rd_p_all_seeds_25/
# 5.0
# ./py150Results/rd_p_all_seeds_26/
# Te	 ES_0  66.66 0.15 68.16 0.07
# ID 	 ES_0  70.08 0.39 70.24 0.38
# Te	 ES_1  66.32 0.06 68.27 0.01
# ID 	 ES_1  69.34 0.74 70.22 0.51
#
#
#  3_ 0_ 8e-05_ 2_ 6
# 10.0
# ./py150Results/rd_p_all_seeds_27/
# 10.0
# ./py150Results/rd_p_all_seeds_28/
# 4.0
# ./py150Results/rd_p_all_seeds_29/
# Te	 ES_0  64.49 0.10 66.80 0.04
# ID 	 ES_0  67.65 0.88 68.74 0.59
# Te	 ES_1  64.45 0.13 66.81 0.04
# ID 	 ES_1  67.17 0.57 68.46 0.35
#
#
#  3_ 1_ 8e-05_ 2_ 6
# 14.0
# ./py150Results/rd_p_all_seeds_30/
# 10.0
# ./py150Results/rd_p_all_seeds_31/
# 5.0
# ./py150Results/rd_p_all_seeds_32/
# Te	 ES_0  64.49 0.10 66.80 0.04
# ID 	 ES_0  67.65 0.88 68.74 0.59
# Te	 ES_1  64.45 0.13 66.81 0.04
# ID 	 ES_1  67.17 0.57 68.46 0.35
#
#
#  3_ 3_ 8e-05_ 2_ 6
# 10.0
# ./py150Results/rd_p_all_seeds_33/
# 14.0
# ./py150Results/rd_p_all_seeds_34/
# 5.0
# ./py150Results/rd_p_all_seeds_35/
# Te	 ES_0  64.49 0.10 66.80 0.04
# ID 	 ES_0  67.65 0.88 68.74 0.59
# Te	 ES_1  64.45 0.13 66.81 0.04
# ID 	 ES_1  67.17 0.57 68.46 0.35

# %% [markdown]
# # Mol

# %%
log_dicts = sorted(glob.glob('./RD_mol*/'), key= lambda x:int(x.split('_')[-1].split('/')[0]))

# %%
my_keys = ['Dataset', 'Algorithm', 'Uniform over groups', 'Distinct groups', 'N groups per batch']
my_keys += ['Batch size', 'Rd type', 'Warm start epoch', 'Control only direction', 'Only inconsistent']
my_keys += ['Without sampling', 'Lr', 'Weight decay', 'Seed']

# %%
exps = {}
for log_di in log_dicts:
    dat_conf = parse_config(log_di, my_keys)
    print(log_di, dat_conf['Lr'])
    exp_name = "{}_{}_{}_{}_{}".format(dat_conf['Warm start epoch'], dat_conf['Rd type'], 
                                 dat_conf['Batch size'], dat_conf['N groups per batch'],
                                 dat_conf['Lr'])
    if exp_name not in exps:
        exps[exp_name] = {}
    exps[exp_name][dat_conf['Seed']] = (read_to_dict(log_di+'test_eval.csv'), 
                                        read_to_dict(log_di+'val_eval.csv'), 
                                        None,
                                        read_to_dict(log_di+'train_eval.csv'),
                                        log_di)
# Out:
# ./RD_mol_0/  0.001
# ./RD_mols_0/  0.001
# ./RD_mols_1/  0.001
# ./RD_mol_1/  0.001
# ./RD_mol_2/  0.001
# ./RD_mol_3/  0.001
# ./RD_mols_3/  0.001
# ./RD_mol_4/  0.001
# ./RD_mols_4/  0.001
# ./RD_mols_5/  0.001
# ./RD_mol_5/  0.001
# ./RD_mol_6/  0.001
# ./RD_mols_7/  0.001
# ./RD_mol_7/  0.001
# ./RD_mol_8/  0.0005
# ./RD_mol_9/  0.0005
# ./RD_mol_10/  0.0005
# ./RD_mol_11/  0.0005
# ./RD_mol_12/  0.0005
# ./RD_mol_13/  0.0005
# ./RD_mol_14/  0.0005
# ./RD_mol_15/  0.0005
# ./RD_mol_16/  0.001
# ./RD_mols_16/  0.001
# ./RD_mol_17/  0.001
# ./RD_mol_18/  0.001
# ./RD_mols_18/  0.001
# ./RD_mol_19/  0.001
# ./RD_mols_19/  0.001
# ./RD_mol_20/  0.001
# ./RD_mols_20/  0.001
# ./RD_mol_21/  0.001
# ./RD_mols_22/  0.001
# ./RD_mol_22/  0.001
# ./RD_mol_23/  0.001
# ./RD_mols_23/  0.001
# ./RD_mols_24/  0.001
# ./RD_mol_24/  0.001
# ./RD_mol_25/  0.001
# ./RD_mols_26/  0.001
# ./RD_mol_26/  0.001
# ./RD_mols_27/  0.001
# ./RD_mol_27/  0.001
# ./RD_mol_28/  0.001
# ./RD_mols_28/  0.001
# ./RD_mol_29/  0.001
# ./RD_mol_30/  0.001
# ./RD_mols_30/  0.001
# ./RD_mol_31/  0.001
# ./RD_mols_31/  0.001

# %%
for exp_id in exps:
    print("'{}'".format(exp_id))
    for kk in exps[exp_id]:
        print(np.max(exps[exp_id][kk][0]['epoch']))
        print(exps[exp_id][kk][4])

    resO = collect_results(exps[exp_id], ('ap', 'ap'), 1, None)

    for alg in resO:
        res_test_str = "ES_{} ".format(alg) +print_row(resO[alg]['test'], ('ap', 'ap'))
        res_id_t_str = "ES_{} ".format(alg) +print_row(resO[alg]['val'], ('ap', 'ap'))
        res_train_str = "ES_{} ".format(alg) +print_row(resO[alg]['train'], ('ap', 'ap'))

        print("Te\t", res_test_str)
        print("ID \t", res_id_t_str)
        print("Tr \t", res_train_str)
        break
    print('\n')
# Out:
# ' -1_ 0_ 32_ 32_ 0.001'
# 10.0
# ./RD_mol_0/
# 8.0
# ./RD_mols_0/
# Te	 ES_0  15.44 0.34 15.44 0.34
# ID 	 ES_0  15.48 0.33 15.48 0.33
# Tr 	 ES_0  13.99 0.31 13.99 0.31
#
#
# ' -1_ 1_ 32_ 32_ 0.001'
# 7.0
# ./RD_mols_1/
# 14.0
# ./RD_mol_1/
# Te	 ES_0  16.34 1.37 16.34 1.37
# ID 	 ES_0  16.17 1.36 16.17 1.36
# Tr 	 ES_0  14.57 1.22 14.57 1.22
#
#
# ' -1_ 2_ 32_ 32_ 0.001'
# 2.0
# ./RD_mol_2/
# Te	 ES_0  11.61 0.00 11.61 0.00
# ID 	 ES_0  10.96 0.00 10.96 0.00
# Tr 	 ES_0  9.19 0.00 9.19 0.00
#
#
# ' -1_ 3_ 32_ 32_ 0.001'
# 14.0
# ./RD_mol_3/
# 7.0
# ./RD_mols_3/
# Te	 ES_0  15.72 0.92 15.72 0.92
# ID 	 ES_0  15.76 0.92 15.76 0.92
# Tr 	 ES_0  14.53 1.56 14.53 1.56
#
#
# ' 40_ 0_ 32_ 32_ 0.001'
# 55.0
# ./RD_mol_4/
# 47.0
# ./RD_mols_4/
# Te	 ES_0  24.62 0.12 24.62 0.12
# ID 	 ES_0  24.99 0.05 24.99 0.05
# Tr 	 ES_0  28.74 0.22 28.74 0.22
#
#
# ' 40_ 1_ 32_ 32_ 0.001'
# 48.0
# ./RD_mols_5/
# 55.0
# ./RD_mol_5/
# Te	 ES_0  24.43 0.09 24.43 0.09
# ID 	 ES_0  25.19 0.04 25.19 0.04
# Tr 	 ES_0  28.72 0.57 28.72 0.57
#
#
# ' 40_ 2_ 32_ 32_ 0.001'
# 43.0
# ./RD_mol_6/
# Te	 ES_0  24.32 0.00 24.32 0.00
# ID 	 ES_0  25.80 0.00 25.80 0.00
# Tr 	 ES_0  27.18 0.00 27.18 0.00
#
#
# ' 40_ 3_ 32_ 32_ 0.001'
# 48.0
# ./RD_mols_7/
# 53.0
# ./RD_mol_7/
# Te	 ES_0  24.60 0.30 24.60 0.30
# ID 	 ES_0  25.09 0.15 25.09 0.15
# Tr 	 ES_0  28.96 0.03 28.96 0.03
#
#
# ' -1_ 0_ 32_ 32_ 0.0005'
# 2.0
# ./RD_mol_8/
# Te	 ES_0  11.44 0.00 11.44 0.00
# ID 	 ES_0  11.00 0.00 11.00 0.00
# Tr 	 ES_0  8.87 0.00 8.87 0.00
#
#
# ' -1_ 1_ 32_ 32_ 0.0005'
# 2.0
# ./RD_mol_9/
# Te	 ES_0  11.19 0.00 11.19 0.00
# ID 	 ES_0  10.68 0.00 10.68 0.00
# Tr 	 ES_0  8.95 0.00 8.95 0.00
#
#
# ' -1_ 2_ 32_ 32_ 0.0005'
# 1.0
# ./RD_mol_10/
# Te	 ES_0  10.02 0.00 10.02 0.00
# ID 	 ES_0  9.83 0.00 9.83 0.00
# Tr 	 ES_0  7.54 0.00 7.54 0.00
#
#
# ' -1_ 3_ 32_ 32_ 0.0005'
# 2.0
# ./RD_mol_11/
# Te	 ES_0  10.94 0.00 10.94 0.00
# ID 	 ES_0  10.45 0.00 10.45 0.00
# Tr 	 ES_0  8.81 0.00 8.81 0.00
#
#
# ' 40_ 0_ 32_ 32_ 0.0005'
# 43.0
# ./RD_mol_12/
# Te	 ES_0  24.34 0.00 24.34 0.00
# ID 	 ES_0  24.81 0.00 24.81 0.00
# Tr 	 ES_0  28.44 0.00 28.44 0.00
#
#
# ' 40_ 1_ 32_ 32_ 0.0005'
# 43.0
# ./RD_mol_13/
# Te	 ES_0  24.80 0.00 24.80 0.00
# ID 	 ES_0  25.07 0.00 25.07 0.00
# Tr 	 ES_0  28.16 0.00 28.16 0.00
#
#
# ' 40_ 2_ 32_ 32_ 0.0005'
# 43.0
# ./RD_mol_14/
# Te	 ES_0  25.43 0.00 25.43 0.00
# ID 	 ES_0  25.12 0.00 25.12 0.00
# Tr 	 ES_0  28.91 0.00 28.91 0.00
#
#
# ' 40_ 3_ 32_ 32_ 0.0005'
# 43.0
# ./RD_mol_15/
# Te	 ES_0  24.37 0.00 24.37 0.00
# ID 	 ES_0  24.78 0.00 24.78 0.00
# Tr 	 ES_0  27.02 0.00 27.02 0.00
#
#
# ' -1_ 0_ 64_ 32_ 0.001'
# 25.0
# ./RD_mol_16/
# 17.0
# ./RD_mols_16/
# Te	 ES_0  18.88 0.50 18.88 0.50
# ID 	 ES_0  18.74 0.60 18.74 0.60
# Tr 	 ES_0  17.05 1.34 17.05 1.34
#
#
# ' -1_ 1_ 64_ 32_ 0.001'
# 6.0
# ./RD_mol_17/
# Te	 ES_0  13.82 0.00 13.82 0.00
# ID 	 ES_0  13.64 0.00 13.64 0.00
# Tr 	 ES_0  11.83 0.00 11.83 0.00
#
#
# ' -1_ 2_ 64_ 32_ 0.001'
# 28.0
# ./RD_mol_18/
# 17.0
# ./RD_mols_18/
# Te	 ES_0  18.47 0.85 18.47 0.85
# ID 	 ES_0  18.70 0.99 18.70 0.99
# Tr 	 ES_0  17.69 0.99 17.69 0.99
#
#
# ' -1_ 3_ 64_ 32_ 0.001'
# 28.0
# ./RD_mol_19/
# 17.0
# ./RD_mols_19/
# Te	 ES_0  18.91 0.61 18.91 0.61
# ID 	 ES_0  18.63 0.77 18.63 0.77
# Tr 	 ES_0  17.05 1.47 17.05 1.47
#
#
# ' 40_ 0_ 64_ 32_ 0.001'
# 72.0
# ./RD_mol_20/
# 57.0
# ./RD_mols_20/
# Te	 ES_0  24.64 0.32 24.64 0.32
# ID 	 ES_0  25.40 0.01 25.40 0.01
# Tr 	 ES_0  28.97 0.17 28.97 0.17
#
#
# ' 40_ 1_ 64_ 32_ 0.001'
# 46.0
# ./RD_mol_21/
# Te	 ES_0  24.75 0.00 24.75 0.00
# ID 	 ES_0  26.02 0.00 26.02 0.00
# Tr 	 ES_0  29.18 0.00 29.18 0.00
#
#
# ' 40_ 2_ 64_ 32_ 0.001'
# 57.0
# ./RD_mols_22/
# 71.0
# ./RD_mol_22/
# Te	 ES_0  25.12 0.01 25.12 0.01
# ID 	 ES_0  25.60 0.17 25.60 0.17
# Tr 	 ES_0  29.07 0.14 29.07 0.14
#
#
# ' 40_ 3_ 64_ 32_ 0.001'
# 72.0
# ./RD_mol_23/
# 57.0
# ./RD_mols_23/
# Te	 ES_0  24.61 0.32 24.61 0.32
# ID 	 ES_0  25.21 0.07 25.21 0.07
# Tr 	 ES_0  29.58 0.02 29.58 0.02
#
#
# ' -1_ 0_ 64_ 64_ 0.001'
# 8.0
# ./RD_mols_24/
# 14.0
# ./RD_mol_24/
# Te	 ES_0  15.81 0.91 15.81 0.91
# ID 	 ES_0  15.91 0.92 15.91 0.92
# Tr 	 ES_0  14.74 1.28 14.74 1.28
#
#
# ' -1_ 1_ 64_ 64_ 0.001'
# 2.0
# ./RD_mol_25/
# Te	 ES_0  11.72 0.00 11.72 0.00
# ID 	 ES_0  11.07 0.00 11.07 0.00
# Tr 	 ES_0  8.51 0.00 8.51 0.00
#
#
# ' -1_ 2_ 64_ 64_ 0.001'
# 8.0
# ./RD_mols_26/
# 14.0
# ./RD_mol_26/
# Te	 ES_0  16.51 0.70 16.51 0.70
# ID 	 ES_0  16.13 0.73 16.13 0.73
# Tr 	 ES_0  14.97 1.45 14.97 1.45
#
#
# ' -1_ 3_ 64_ 64_ 0.001'
# 8.0
# ./RD_mols_27/
# 14.0
# ./RD_mol_27/
# Te	 ES_0  15.98 0.90 15.98 0.90
# ID 	 ES_0  15.98 0.73 15.98 0.73
# Tr 	 ES_0  14.47 1.19 14.47 1.19
#
#
# ' 40_ 0_ 64_ 64_ 0.001'
# 55.0
# ./RD_mol_28/
# 48.0
# ./RD_mols_28/
# Te	 ES_0  25.07 0.17 25.07 0.17
# ID 	 ES_0  26.39 0.09 26.39 0.09
# Tr 	 ES_0  31.77 0.30 31.77 0.30
#
#
# ' 40_ 1_ 64_ 64_ 0.001'
# 43.0
# ./RD_mol_29/
# Te	 ES_0  25.03 0.00 25.03 0.00
# ID 	 ES_0  26.19 0.00 26.19 0.00
# Tr 	 ES_0  32.03 0.00 32.03 0.00
#
#
# ' 40_ 2_ 64_ 64_ 0.001'
# 55.0
# ./RD_mol_30/
# 47.0
# ./RD_mols_30/
# Te	 ES_0  25.44 0.32 25.44 0.32
# ID 	 ES_0  26.29 0.24 26.29 0.24
# Tr 	 ES_0  31.81 0.11 31.81 0.11
#
#
# ' 40_ 3_ 64_ 64_ 0.001'
# 55.0
# ./RD_mol_31/
# 47.0
# ./RD_mols_31/
# Te	 ES_0  25.39 0.28 25.39 0.28
# ID 	 ES_0  26.16 0.30 26.16 0.30
# Tr 	 ES_0  31.89 0.44 31.89 0.44

# %%
exps.keys()
# Out:
# dict_keys([])

# %% [markdown]
# # FMOW

# %%
log_dicts = sorted(glob.glob('./FowResults/WBN*/'), key= lambda x:int(x.split('_')[-1].split('/')[0]))

# %%
my_keys = ['Dataset', 'Algorithm', 'Uniform over groups', 'Distinct groups', 'N groups per batch']
my_keys += ['Batch size', 'Rd type', 'Warm start epoch', 'Control only direction', 'Only inconsistent']
my_keys += ['Without sampling', 'Lr', 'Weight decay', 'Seed']

# %%
exps = {}
for log_di in log_dicts:
    dat_conf = parse_config(log_di, my_keys)
    if not dat_conf['Dataset'] == ' fmow':
        continue
    print(log_di, dat_conf['Lr'])
    exp_name = "{}_{}_{}_{}_{}".format(dat_conf['Warm start epoch'], dat_conf['Rd type'], 
                                 dat_conf['Batch size'], dat_conf['N groups per batch'],
                                 dat_conf['Lr'])
    if exp_name not in exps:
        exps[exp_name] = {}
    exps[exp_name][dat_conf['Seed']] = (read_to_dict(log_di+'test_eval.csv'), 
                                        read_to_dict(log_di+'val_eval.csv'), 
                                        read_to_dict(log_di+'id_test_eval.csv'),
                                        read_to_dict(log_di+'train_eval.csv'),
                                        log_di)
# Out:
# ./FowResults/WBN_rd_fow_0/  0.0001
# ./FowResults/WBN_rd_fow_1/  0.0001
# ./FowResults/WBN_rd_fow_2/  0.0001
# ./FowResults/WBN_rd_fow_3/  0.0001
# ./FowResults/WBN_rd_fow_4/  0.0001
# ./FowResults/WBN_rd_fow_5/  0.0001
# ./FowResults/WBN_rd_fow_6/  0.0001
# ./FowResults/WBN_rd_fow_7/  0.0001
# ./FowResults/WBN_rd_fow_8/  0.0005
# ./FowResults/WBN_rd_fow_9/  0.0005
# ./FowResults/WBN_rd_fow_10/  0.0005
# ./FowResults/WBN_rd_fow_11/  0.0005
# ./FowResults/WBN_rd_fow_12/  0.0005
# ./FowResults/WBN_rd_fow_13/  0.0005
# ./FowResults/WBN_rd_fow_14/  0.0005
# ./FowResults/WBN_rd_fow_15/  0.0005
# ./FowResults/WBN_rd_fow_16/  0.0005
# ./FowResults/WBN_rd_fow_17/  0.0005
# ./FowResults/WBN_rd_fow_18/  0.0005
# ./FowResults/WBN_rd_fow_19/  0.0005
# ./FowResults/WBN_rd_fow_20/  0.0005
# ./FowResults/WBN_rd_fow_21/  0.0005
# ./FowResults/WBN_rd_fow_22/  0.0005
# ./FowResults/WBN_rd_fow_23/  0.0005
# ./FowResults/WBN_rd_fow_50/  0.0001
# ./FowResults/WBN_rd_fow_51/  0.0001
# ./FowResults/WBN_rd_fow_52/  0.0001
# ./FowResults/WBN_rd_fow_53/  0.0001
# ./FowResults/WBN_rd_fow_54/  0.0001
# ./FowResults/WBN_rd_fow_55/  0.0001
# ./FowResults/WBN_rd_fow_56/  0.0001
# ./FowResults/WBN_rd_fow_57/  0.0001
# ./FowResults/WBN_rd_fow_58/  0.0005
# ./FowResults/WBN_rd_fow_59/  0.0005
# ./FowResults/WBN_rd_fow_60/  0.0005
# ./FowResults/WBN_rd_fow_61/  0.0005
# ./FowResults/WBN_rd_fow_62/  0.0005
# ./FowResults/WBN_rd_fow_63/  0.0005
# ./FowResults/WBN_rd_fow_64/  0.0005
# ./FowResults/WBN_rd_fow_65/  0.0005
# ./FowResults/WBN_rd_fow_154/  0.0001
# ./FowResults/WBN_rd_fow_156/  0.0001
# ./FowResults/WBN_rd_fow_162/  0.0005
# ./FowResults/WBN_rd_fow_163/  0.0005

# %%
for exp_id in exps:
    if ' '.join(exp_id.split(' ')[:-1]) not in [' 3_ 0_ 32_ 4_', ' 3_ 2_ 32_ 4_', ' 3_ 0_ 64_ 4_']:
        continue
    print("'{}'".format(exp_id))
    for kk in exps[exp_id]:
        print(np.max(exps[exp_id][kk][0]['epoch']))
        print(exps[exp_id][kk][4])

    resO = collect_results(exps[exp_id], ('acc_avg', 'acc_worst_region'), 0, None)

    for alg in resO:
        res_test_str = "ES_{} ".format(alg) +print_row(resO[alg]['test'], ('acc_avg', 'acc_worst_region'))
        res_id_t_str = "ES_{} ".format(alg) +print_row(resO[alg]['id_test'], ('acc_avg', 'acc_worst_region'))
        res_train_str = "ES_{} ".format(alg) +print_row(resO[alg]['train'], ('acc_avg', 'acc_worst_region'))

        print("Te\t", res_test_str)
        print("ID \t", res_id_t_str)
        print("Tr \t", res_train_str)
    print('\n')
# Out:
# ' 3_ 0_ 32_ 4_ 0.0001'
# 46.0
# ./FowResults/WBN_rd_fow_4/
# 46.0
# ./FowResults/WBN_rd_fow_54/
# 46.0
# ./FowResults/WBN_rd_fow_154/
# Te	 ES_0  52.77 0.29 34.44 1.07
# ID 	 ES_0  59.19 0.08 57.68 0.40
# Tr 	 ES_0  99.77 0.21 99.71 0.19
# Te	 ES_1  52.27 0.64 35.36 0.41
# ID 	 ES_1  58.96 0.52 57.63 0.19
# Tr 	 ES_1  99.21 1.01 98.93 1.35
#
#
# ' 3_ 2_ 32_ 4_ 0.0001'
# 46.0
# ./FowResults/WBN_rd_fow_6/
# 46.0
# ./FowResults/WBN_rd_fow_56/
# 49.0
# ./FowResults/WBN_rd_fow_156/
# Te	 ES_0  53.00 0.22 32.66 0.72
# ID 	 ES_0  59.59 0.51 57.60 0.81
# Tr 	 ES_0  99.96 0.04 99.94 0.05
# Te	 ES_1  52.28 0.80 33.08 0.62
# ID 	 ES_1  58.89 0.54 56.85 0.93
# Tr 	 ES_1  99.26 0.98 99.02 1.27
#
#
# ' 3_ 0_ 64_ 4_ 0.0005'
# 49.0
# ./FowResults/WBN_rd_fow_16/
# 49.0
# ./FowResults/WBN_rd_fow_62/
# 49.0
# ./FowResults/WBN_rd_fow_162/
# Te	 ES_0  52.51 0.17 33.19 0.56
# ID 	 ES_0  59.31 0.23 57.61 0.87
# Tr 	 ES_0  99.92 0.05 99.86 0.09
# Te	 ES_1  51.83 0.60 33.72 0.24
# ID 	 ES_1  58.44 0.63 56.64 0.52
# Tr 	 ES_1  99.54 0.46 99.45 0.48

# %% [markdown]
# # Cam

# %%
log_dicts = sorted(glob.glob('./CamelyonResults/rd_cam*/'), key= lambda x:int(re.sub('s','',x).split('_')[-1].split('/')[0]))

# %%
my_keys = ['Dataset', 'Algorithm', 'Uniform over groups', 'Distinct groups', 'N groups per batch']
my_keys += ['Batch size', 'Rd type', 'Warm start epoch', 'Control only direction', 'Only inconsistent']
my_keys += ['Without sampling', 'Lr', 'Weight decay', 'Seed']

# %%
exps = {}
for log_di in log_dicts:
    dat_conf = parse_config(log_di, my_keys)
    print(log_di, dat_conf['Lr'])
    exp_name = "{}_{}_{}_{}_{}".format(dat_conf['Warm start epoch'], dat_conf['Rd type'], 
                                 dat_conf['Lr'], dat_conf['N groups per batch'],
                                 dat_conf['Batch size'])
    if exp_name not in exps:
        exps[exp_name] = {}
    exps[exp_name][dat_conf['Seed']] = (read_to_dict(log_di+'test_eval.csv'), 
                                        read_to_dict(log_di+'val_eval.csv'), 
                                        read_to_dict(log_di+'id_val_eval.csv'),
                                        read_to_dict(log_di+'train_eval.csv'),
                                        log_di)
# Out:
# ./CamelyonResults/rd_cam_0/  0.005
# ./CamelyonResults/rd_cam_sss1/  0.005
# ./CamelyonResults/rd_cam_s1/  0.005
# ./CamelyonResults/rd_cam_1/  0.005
# ./CamelyonResults/rd_cam_ss1/  0.005
# ./CamelyonResults/rd_cam_2/  0.005
# ./CamelyonResults/rd_cam_s3/  0.005
# ./CamelyonResults/rd_cam_3/  0.005
# ./CamelyonResults/rd_cam_ss3/  0.005
# ./CamelyonResults/rd_cam_4/  0.005
# ./CamelyonResults/rd_cam_ss5/  0.005
# ./CamelyonResults/rd_cam_s5/  0.005
# ./CamelyonResults/rd_cam_5/  0.005
# ./CamelyonResults/rd_cam_6/  0.005
# ./CamelyonResults/rd_cam_7/  0.005
# ./CamelyonResults/rd_cam_s7/  0.005
# ./CamelyonResults/rd_cam_ss7/  0.005
# ./CamelyonResults/rd_cam_8/  0.005
# ./CamelyonResults/rd_cam_s9/  0.005
# ./CamelyonResults/rd_cam_9/  0.005
# ./CamelyonResults/rd_cam_ss9/  0.005
# ./CamelyonResults/rd_cam_10/  0.005
# ./CamelyonResults/rd_cam_11/  0.005
# ./CamelyonResults/rd_cam_ss11/  0.005
# ./CamelyonResults/rd_cam_12/  0.01
# ./CamelyonResults/rd_cam_s13/  0.01
# ./CamelyonResults/rd_cam_13/  0.01
# ./CamelyonResults/rd_cam_14/  0.01
# ./CamelyonResults/rd_cam_15/  0.01
# ./CamelyonResults/rd_cam_16/  0.01
# ./CamelyonResults/rd_cam_17/  0.01
# ./CamelyonResults/rd_cam_s17/  0.01
# ./CamelyonResults/rd_cam_18/  0.01
# ./CamelyonResults/rd_cam_19/  0.01
# ./CamelyonResults/rd_cam_20/  0.01
# ./CamelyonResults/rd_cam_21/  0.01
# ./CamelyonResults/rd_cam_22/  0.01
# ./CamelyonResults/rd_cam_23/  0.01
# ./CamelyonResults/rd_cam_ss24/  0.005
# ./CamelyonResults/rd_cam_s24/  0.005
# ./CamelyonResults/rd_cam_24/  0.005
# ./CamelyonResults/rd_cam_sss25/  0.005
# ./CamelyonResults/rd_cam_ss25/  0.005
# ./CamelyonResults/rd_cam_s25/  0.005
# ./CamelyonResults/rd_cam_25/  0.005
# ./CamelyonResults/rd_cam_s26/  0.005
# ./CamelyonResults/rd_cam_26/  0.005
# ./CamelyonResults/rd_cam_s27/  0.005
# ./CamelyonResults/rd_cam_sss27/  0.005
# ./CamelyonResults/rd_cam_ss27/  0.005
# ./CamelyonResults/rd_cam_27/  0.005
# ./CamelyonResults/rd_cam_s28/  0.005
# ./CamelyonResults/rd_cam_ss28/  0.005
# ./CamelyonResults/rd_cam_28/  0.005
# ./CamelyonResults/rd_cam_29/  0.005
# ./CamelyonResults/rd_cam_ss29/  0.005
# ./CamelyonResults/rd_cam_s29/  0.005
# ./CamelyonResults/rd_cam_s30/  0.005
# ./CamelyonResults/rd_cam_30/  0.005
# ./CamelyonResults/rd_cam_s31/  0.005
# ./CamelyonResults/rd_cam_ss31/  0.005
# ./CamelyonResults/rd_cam_31/  0.005
# ./CamelyonResults/rd_cam_ss32/  0.005
# ./CamelyonResults/rd_cam_32/  0.005
# ./CamelyonResults/rd_cam_ss33/  0.005
# ./CamelyonResults/rd_cam_s33/  0.005
# ./CamelyonResults/rd_cam_33/  0.005
# ./CamelyonResults/rd_cam_34/  0.005
# ./CamelyonResults/rd_cam_ss35/  0.005
# ./CamelyonResults/rd_cam_35/  0.005
# ./CamelyonResults/rd_cam_s35/  0.005
# ./CamelyonResults/rd_cam_36/  0.01
# ./CamelyonResults/rd_cam_ss36/  0.01
# ./CamelyonResults/rd_cam_s36/  0.01
# ./CamelyonResults/rd_cam_37/  0.01
# ./CamelyonResults/rd_cam_s37/  0.01
# ./CamelyonResults/rd_cam_38/  0.01
# ./CamelyonResults/rd_cam_s39/  0.01
# ./CamelyonResults/rd_cam_ss39/  0.01
# ./CamelyonResults/rd_cam_39/  0.01
# ./CamelyonResults/rd_cam_sss39/  0.01
# ./CamelyonResults/rd_cam_ss40/  0.01
# ./CamelyonResults/rd_cam_40/  0.01
# ./CamelyonResults/rd_cam_s40/  0.01
# ./CamelyonResults/rd_cam_41/  0.01
# ./CamelyonResults/rd_cam_s41/  0.01
# ./CamelyonResults/rd_cam_42/  0.01
# ./CamelyonResults/rd_cam_s43/  0.01
# ./CamelyonResults/rd_cam_43/  0.01
# ./CamelyonResults/rd_cam_ss43/  0.01
# ./CamelyonResults/rd_cam_44/  0.01
# ./CamelyonResults/rd_cam_ss44/  0.01
# ./CamelyonResults/rd_cam_45/  0.01
# ./CamelyonResults/rd_cam_46/  0.01
# ./CamelyonResults/rd_cam_ss47/  0.01
# ./CamelyonResults/rd_cam_47/  0.01
# ./CamelyonResults/rd_cam_s47/  0.01
# ./CamelyonResults/rd_cam_48/  0.005
# ./CamelyonResults/rd_cam_s48/  0.005
# ./CamelyonResults/rd_cam_ss49/  0.005
# ./CamelyonResults/rd_cam_49/  0.005
# ./CamelyonResults/rd_cam_s49/  0.005
# ./CamelyonResults/rd_cam_50/  0.005
# ./CamelyonResults/rd_cam_s50/  0.005
# ./CamelyonResults/rd_cam_s51/  0.005
# ./CamelyonResults/rd_cam_51/  0.005
# ./CamelyonResults/rd_cam_s52/  0.005
# ./CamelyonResults/rd_cam_52/  0.005
# ./CamelyonResults/rd_cam_s53/  0.005
# ./CamelyonResults/rd_cam_ss53/  0.005
# ./CamelyonResults/rd_cam_53/  0.005
# ./CamelyonResults/rd_cam_s54/  0.005
# ./CamelyonResults/rd_cam_54/  0.005
# ./CamelyonResults/rd_cam_55/  0.005
# ./CamelyonResults/rd_cam_s55/  0.005
# ./CamelyonResults/rd_cam_56/  0.005
# ./CamelyonResults/rd_cam_57/  0.005
# ./CamelyonResults/rd_cam_ss57/  0.005
# ./CamelyonResults/rd_cam_58/  0.005
# ./CamelyonResults/rd_cam_59/  0.005
# ./CamelyonResults/rd_cam_s60/  0.01
# ./CamelyonResults/rd_cam_60/  0.01
# ./CamelyonResults/rd_cam_61/  0.01
# ./CamelyonResults/rd_cam_62/  0.01
# ./CamelyonResults/rd_cam_63/  0.01
# ./CamelyonResults/rd_cam_64/  0.01
# ./CamelyonResults/rd_cam_s64/  0.01
# ./CamelyonResults/rd_cam_65/  0.01
# ./CamelyonResults/rd_cam_66/  0.01
# ./CamelyonResults/rd_cam_67/  0.01
# ./CamelyonResults/rd_cam_68/  0.01
# ./CamelyonResults/rd_cam_69/  0.01
# ./CamelyonResults/rd_cam_70/  0.01
# ./CamelyonResults/rd_cam_71/  0.01
# ./CamelyonResults/rd_cam_ss72/  0.005
# ./CamelyonResults/rd_cam_s72/  0.005
# ./CamelyonResults/rd_cam_72/  0.005
# ./CamelyonResults/rd_cam_73/  0.005
# ./CamelyonResults/rd_cam_74/  0.005
# ./CamelyonResults/rd_cam_75/  0.005
# ./CamelyonResults/rd_cam_s75/  0.005
# ./CamelyonResults/rd_cam_76/  0.005
# ./CamelyonResults/rd_cam_ss76/  0.005
# ./CamelyonResults/rd_cam_s76/  0.005
# ./CamelyonResults/rd_cam_77/  0.005
# ./CamelyonResults/rd_cam_78/  0.005
# ./CamelyonResults/rd_cam_s79/  0.005
# ./CamelyonResults/rd_cam_79/  0.005
# ./CamelyonResults/rd_cam_ss80/  0.005
# ./CamelyonResults/rd_cam_80/  0.005
# ./CamelyonResults/rd_cam_81/  0.005
# ./CamelyonResults/rd_cam_82/  0.005
# ./CamelyonResults/rd_cam_83/  0.005
# ./CamelyonResults/rd_cam_84/  0.01
# ./CamelyonResults/rd_cam_ss84/  0.01
# ./CamelyonResults/rd_cam_s84/  0.01
# ./CamelyonResults/rd_cam_s85/  0.01
# ./CamelyonResults/rd_cam_ss85/  0.01
# ./CamelyonResults/rd_cam_85/  0.01
# ./CamelyonResults/rd_cam_s86/  0.01
# ./CamelyonResults/rd_cam_ss86/  0.01
# ./CamelyonResults/rd_cam_86/  0.01
# ./CamelyonResults/rd_cam_sss86/  0.01
# ./CamelyonResults/rd_cam_s87/  0.01
# ./CamelyonResults/rd_cam_87/  0.01
# ./CamelyonResults/rd_cam_ss88/  0.01
# ./CamelyonResults/rd_cam_88/  0.01
# ./CamelyonResults/rd_cam_s88/  0.01
# ./CamelyonResults/rd_cam_89/  0.01
# ./CamelyonResults/rd_cam_ss89/  0.01
# ./CamelyonResults/rd_cam_s89/  0.01
# ./CamelyonResults/rd_cam_ss90/  0.01
# ./CamelyonResults/rd_cam_90/  0.01
# ./CamelyonResults/rd_cam_s90/  0.01
# ./CamelyonResults/rd_cam_91/  0.01
# ./CamelyonResults/rd_cam_s91/  0.01
# ./CamelyonResults/rd_cam_ss92/  0.01
# ./CamelyonResults/rd_cam_92/  0.01
# ./CamelyonResults/rd_cam_ss93/  0.01
# ./CamelyonResults/rd_cam_93/  0.01
# ./CamelyonResults/rd_cam_ss94/  0.01
# ./CamelyonResults/rd_cam_94/  0.01
# ./CamelyonResults/rd_cam_s94/  0.01
# ./CamelyonResults/rd_cam_95/  0.01

# %%
exps[exp_id][' 9'][0].keys()
# Out:
# dict_keys(['epoch', 'acc_avg', 'acc_slide:0', 'count_slide:0', 'acc_slide:1', 'count_slide:1', 'acc_slide:2', 'count_slide:2', 'acc_slide:3', 'count_slide:3', 'acc_slide:4', 'count_slide:4', 'acc_slide:5', 'count_slide:5', 'acc_slide:6', 'count_slide:6', 'acc_slide:7', 'count_slide:7', 'acc_slide:8', 'count_slide:8', 'acc_slide:9', 'count_slide:9', 'acc_slide:10', 'count_slide:10', 'acc_slide:11', 'count_slide:11', 'acc_slide:12', 'count_slide:12', 'acc_slide:13', 'count_slide:13', 'acc_slide:14', 'count_slide:14', 'acc_slide:15', 'count_slide:15', 'acc_slide:16', 'count_slide:16', 'acc_slide:17', 'count_slide:17', 'acc_slide:18', 'count_slide:18', 'acc_slide:19', 'count_slide:19', 'acc_slide:20', 'count_slide:20', 'acc_slide:21', 'count_slide:21', 'acc_slide:22', 'count_slide:22', 'acc_slide:23', 'count_slide:23', 'acc_slide:24', 'count_slide:24', 'acc_slide:25', 'count_slide:25', 'acc_slide:26', 'count_slide:26', 'acc_slide:27', 'count_slide:27', 'acc_slide:28', 'count_slide:28', 'acc_slide:29', 'count_slide:29', 'acc_slide:30', 'count_slide:30', 'acc_slide:31', 'count_slide:31', 'acc_slide:32', 'count_slide:32', 'acc_slide:33', 'count_slide:33', 'acc_slide:34', 'count_slide:34', 'acc_slide:35', 'count_slide:35', 'acc_slide:36', 'count_slide:36', 'acc_slide:37', 'count_slide:37', 'acc_slide:38', 'count_slide:38', 'acc_slide:39', 'count_slide:39', 'acc_slide:40', 'count_slide:40', 'acc_slide:41', 'count_slide:41', 'acc_slide:42', 'count_slide:42', 'acc_slide:43', 'count_slide:43', 'acc_slide:44', 'count_slide:44', 'acc_slide:45', 'count_slide:45', 'acc_slide:46', 'count_slide:46', 'acc_slide:47', 'count_slide:47', 'acc_slide:48', 'count_slide:48', 'acc_slide:49', 'count_slide:49', 'acc_wg'])

# %%
for exp_id in exps:
    if exp_id not in [' -1_ 1_ 0.005_ 3_ 30', ' -1_ 1_ 0.005_ 3_ 60', ' -1_ 3_ 0.005_ 3_ 60' ,' -1_ 3_ 0.01_ 3_ 60', ' 1_ 2_ 0.01_ 3_ 60']:
        continue
    print("'{}'".format(exp_id))
    skip_exp = False
    for kk in exps[exp_id]:
        if 'epoch' not in exps[exp_id][kk][0].keys():
            #pint("Error", exps[exp_id][kk][4])
            skip_exp = True
            break
        print(np.max(exps[exp_id][kk][0]['epoch']))
        print(exps[exp_id][kk][4])
    if skip_exp:
        continue
        
    resO = collect_results(exps[exp_id], ('acc_avg', 'acc_avg'), 1, None)

    for alg in resO:
        res_test_str = "ES_{} ".format(alg) +print_row(resO[alg]['test'], ('acc_avg', 'acc_avg'))
        res_id_t_str = "ES_{} ".format(alg) +print_row(resO[alg]['id_test'], ('acc_avg', 'acc_avg'))
        res_train_str = "ES_{} ".format(alg) +print_row(resO[alg]['train'], ('acc_avg', 'acc_avg'))

        print("Te\t", res_test_str)
        print("ID \t", res_id_t_str)
        #print("Tr \t", res_train_str)
    print('\n')
# Out:
# ' -1_ 1_ 0.005_ 3_ 30'
# 2.0
# ./CamelyonResults/rd_cam_sss1/
# 7.0
# ./CamelyonResults/rd_cam_s1/
# 7.0
# ./CamelyonResults/rd_cam_1/
# 1.0
# ./CamelyonResults/rd_cam_ss1/
# 1.0
# ./CamelyonResults/rd_cam_ss5/
# 7.0
# ./CamelyonResults/rd_cam_s5/
# 7.0
# ./CamelyonResults/rd_cam_5/
# 4.0
# ./CamelyonResults/rd_cam_s9/
# 5.0
# ./CamelyonResults/rd_cam_9/
# ' -1_ 1_ 0.005_ 3_ 60'
# 6.0
# ./CamelyonResults/rd_cam_sss25/
# 7.0
# ./CamelyonResults/rd_cam_ss25/
# 7.0
# ./CamelyonResults/rd_cam_s25/
# 7.0
# ./CamelyonResults/rd_cam_25/
# 7.0
# ./CamelyonResults/rd_cam_29/
# 7.0
# ./CamelyonResults/rd_cam_ss29/
# 7.0
# ./CamelyonResults/rd_cam_s29/
# 7.0
# ./CamelyonResults/rd_cam_ss33/
# 7.0
# ./CamelyonResults/rd_cam_s33/
# 7.0
# ./CamelyonResults/rd_cam_33/
# Te	 ES_0  73.95 9.37 73.95 9.37
# ID 	 ES_0  94.83 1.94 94.83 1.94
# Te	 ES_1  73.95 9.37 73.95 9.37
# ID 	 ES_1  94.83 1.94 94.83 1.94
#
#
# ' -1_ 3_ 0.005_ 3_ 60'
# 7.0
# ./CamelyonResults/rd_cam_s27/
# 7.0
# ./CamelyonResults/rd_cam_sss27/
# 7.0
# ./CamelyonResults/rd_cam_ss27/
# 7.0
# ./CamelyonResults/rd_cam_27/
# 7.0
# ./CamelyonResults/rd_cam_s31/
# 7.0
# ./CamelyonResults/rd_cam_ss31/
# 7.0
# ./CamelyonResults/rd_cam_31/
# 7.0
# ./CamelyonResults/rd_cam_ss35/
# 7.0
# ./CamelyonResults/rd_cam_35/
# 7.0
# ./CamelyonResults/rd_cam_s35/
# Te	 ES_0  66.71 9.52 66.71 9.52
# ID 	 ES_0  91.76 6.72 91.76 6.72
# Te	 ES_1  66.71 9.52 66.71 9.52
# ID 	 ES_1  91.76 6.72 91.76 6.72
#
#
# ' -1_ 3_ 0.01_ 3_ 60'
# 7.0
# ./CamelyonResults/rd_cam_s39/
# 7.0
# ./CamelyonResults/rd_cam_ss39/
# 7.0
# ./CamelyonResults/rd_cam_39/
# 7.0
# ./CamelyonResults/rd_cam_sss39/
# 7.0
# ./CamelyonResults/rd_cam_s43/
# 7.0
# ./CamelyonResults/rd_cam_43/
# 7.0
# ./CamelyonResults/rd_cam_ss43/
# 7.0
# ./CamelyonResults/rd_cam_ss47/
# 7.0
# ./CamelyonResults/rd_cam_47/
# 7.0
# ./CamelyonResults/rd_cam_s47/
# Te	 ES_0  67.77 10.24 67.77 10.24
# ID 	 ES_0  89.96 6.42 89.96 6.42
# Te	 ES_1  67.77 10.24 67.77 10.24
# ID 	 ES_1  89.96 6.42 89.96 6.42
#
#
# ' 1_ 2_ 0.01_ 3_ 60'
# 7.0
# ./CamelyonResults/rd_cam_s86/
# 7.0
# ./CamelyonResults/rd_cam_ss86/
# 7.0
# ./CamelyonResults/rd_cam_86/
# 7.0
# ./CamelyonResults/rd_cam_sss86/
# 7.0
# ./CamelyonResults/rd_cam_ss90/
# 7.0
# ./CamelyonResults/rd_cam_90/
# 7.0
# ./CamelyonResults/rd_cam_s90/
# 7.0
# ./CamelyonResults/rd_cam_ss94/
# 7.0
# ./CamelyonResults/rd_cam_94/
# 7.0
# ./CamelyonResults/rd_cam_s94/
# Te	 ES_0  67.51 11.07 67.51 11.07
# ID 	 ES_0  88.53 9.56 88.53 9.56
# Te	 ES_1  67.51 11.07 67.51 11.07
# ID 	 ES_1  88.53 9.56 88.53 9.56

# %% [markdown]
# # Poverty

# %%
log_dicts = sorted(glob.glob('./PovertyResults/POV_RD*/'), key= lambda x:int(re.sub('s','',x).split('_')[-1].split('/')[0]))

# %%
my_keys = ['Dataset', 'Algorithm', 'Uniform over groups', 'Distinct groups', 'N groups per batch']
my_keys += ['Batch size', 'Rd type', 'Warm start epoch', 'Control only direction', 'Only inconsistent']
my_keys += ['Without sampling', 'Lr', 'Weight decay', 'Seed', 'Dataset kwargs']

# %%
exps = {}
for log_di in log_dicts:
    #if 'RDE' not in log_di:
    #    continue
    dat_conf = parse_config(log_di, my_keys)
    print(log_di, dat_conf['Lr'])
    exp_name = "{}_{}_{}_{}_{}".format(dat_conf['Warm start epoch'], dat_conf['Rd type'], 
                                 dat_conf['N groups per batch'], dat_conf['Lr'],
                                 dat_conf['Batch size'])
    if exp_name not in exps:
        exps[exp_name] = {}
    exps[exp_name][dat_conf['Dataset kwargs']] = (read_to_dict(log_di+'test_eval.csv'), 
                                        read_to_dict(log_di+'val_eval.csv'), 
                                        read_to_dict(log_di+'id_test_eval.csv'),
                                        read_to_dict(log_di+'id_val_eval.csv'),
                                        log_di)
# Out:
# ./PovertyResults/POV_RDC_0/  0.0001
# ./PovertyResults/POV_RDA_0/  0.0001
# ./PovertyResults/POV_RDE_0/  0.0001
# ./PovertyResults/POV_RD_0/  0.0001
# ./PovertyResults/POV_RDD_0/  0.0001
# ./PovertyResults/POV_RDA_1/  0.0001
# ./PovertyResults/POV_RDC_1/  0.0001
# ./PovertyResults/POV_RDE_1/  0.0001
# ./PovertyResults/POV_RDD_1/  0.0001
# ./PovertyResults/POV_RD_1/  0.0001
# ./PovertyResults/POV_RDE_2/  0.0001
# ./PovertyResults/POV_RD_2/  0.0001
# ./PovertyResults/POV_RDA_2/  0.0001
# ./PovertyResults/POV_RDD_2/  0.0001
# ./PovertyResults/POV_RDC_2/  0.0001
# ./PovertyResults/POV_RDD_3/  0.0001
# ./PovertyResults/POV_RD_3/  0.0001
# ./PovertyResults/POV_RDA_3/  0.0001
# ./PovertyResults/POV_RDC_3/  0.0001
# ./PovertyResults/POV_RDE_3/  0.0001
# ./PovertyResults/POV_RDA_4/  0.0001
# ./PovertyResults/POV_RDE_4/  0.0001
# ./PovertyResults/POV_RDC_4/  0.0001
# ./PovertyResults/POV_RDD_4/  0.0001
# ./PovertyResults/POV_RD_4/  0.0001
# ./PovertyResults/POV_RDD_5/  0.0001
# ./PovertyResults/POV_RDA_5/  0.0001
# ./PovertyResults/POV_RDC_5/  0.0001
# ./PovertyResults/POV_RD_5/  0.0001
# ./PovertyResults/POV_RDE_5/  0.0001
# ./PovertyResults/POV_RDE_6/  0.0001
# ./PovertyResults/POV_RD_6/  0.0001
# ./PovertyResults/POV_RDC_6/  0.0001
# ./PovertyResults/POV_RDA_6/  0.0001
# ./PovertyResults/POV_RDD_6/  0.0001
# ./PovertyResults/POV_RDA_7/  0.0001
# ./PovertyResults/POV_RDC_7/  0.0001
# ./PovertyResults/POV_RDE_7/  0.0001
# ./PovertyResults/POV_RD_7/  0.0001
# ./PovertyResults/POV_RDD_7/  0.0001
# ./PovertyResults/POV_RDC_8/  0.0005
# ./PovertyResults/POV_RD_8/  0.0005
# ./PovertyResults/POV_RDE_8/  0.0005
# ./PovertyResults/POV_RDA_8/  0.0005
# ./PovertyResults/POV_RDD_8/  0.0005
# ./PovertyResults/POV_RDA_9/  0.0005
# ./PovertyResults/POV_RDC_9/  0.0005
# ./PovertyResults/POV_RDE_9/  0.0005
# ./PovertyResults/POV_RDD_9/  0.0005
# ./PovertyResults/POV_RD_9/  0.0005
# ./PovertyResults/POV_RDC_10/  0.0005
# ./PovertyResults/POV_RDA_10/  0.0005
# ./PovertyResults/POV_RD_10/  0.0005
# ./PovertyResults/POV_RDE_10/  0.0005
# ./PovertyResults/POV_RDD_10/  0.0005
# ./PovertyResults/POV_RD_11/  0.0005
# ./PovertyResults/POV_RDA_11/  0.0005
# ./PovertyResults/POV_RDE_11/  0.0005
# ./PovertyResults/POV_RDC_11/  0.0005
# ./PovertyResults/POV_RDD_11/  0.0005
# ./PovertyResults/POV_RDC_12/  0.0005
# ./PovertyResults/POV_RDA_12/  0.0005
# ./PovertyResults/POV_RDE_12/  0.0005
# ./PovertyResults/POV_RD_12/  0.0005
# ./PovertyResults/POV_RDD_12/  0.0005
# ./PovertyResults/POV_RD_13/  0.0005
# ./PovertyResults/POV_RDD_13/  0.0005
# ./PovertyResults/POV_RDC_13/  0.0005
# ./PovertyResults/POV_RDA_13/  0.0005
# ./PovertyResults/POV_RDE_13/  0.0005
# ./PovertyResults/POV_RD_14/  0.0005
# ./PovertyResults/POV_RDA_14/  0.0005
# ./PovertyResults/POV_RDD_14/  0.0005
# ./PovertyResults/POV_RDE_14/  0.0005
# ./PovertyResults/POV_RDC_14/  0.0005
# ./PovertyResults/POV_RD_15/  0.0005
# ./PovertyResults/POV_RDD_15/  0.0005
# ./PovertyResults/POV_RDE_15/  0.0005
# ./PovertyResults/POV_RDA_15/  0.0005
# ./PovertyResults/POV_RDC_15/  0.0005

# %%
for exp_id in exps:
    print("'{}'".format(exp_id))
    for kk in exps[exp_id]:
        print(np.max(exps[exp_id][kk][0]['epoch']))
        print(exps[exp_id][kk][4])
        
    resO = collect_results(exps[exp_id], ('r_all', 'r_wg'), 0, None)

    for alg in resO:
        res_test_str = "OOD_{} ".format(alg) +print_row(resO[alg]['test'], ('r_all', 'r_wg'))
        res_id_t_str = "ID_{} ".format(alg) +print_row(resO[alg]['id_test'], ('r_all', 'r_wg'))
        res_train_str = "TR_{} ".format(alg) +print_row(resO[alg]['train'], ('r_all', 'r_wg'))
        res_val_str = "VAL_{} ".format(alg) +print_row(resO[alg]['val'], ('r_all', 'r_wg'))

        print(res_test_str)
        print(res_id_t_str)
        print(res_train_str)
        print(res_val_str)
    print('\n')
# Out:
# ' -1_ 0_ 4_ 0.0001_ 32'
# 199.0
# ./PovertyResults/POV_RDC_0/
# 199.0
# ./PovertyResults/POV_RDA_0/
# 199.0
# ./PovertyResults/POV_RDE_0/
# 199.0
# ./PovertyResults/POV_RD_0/
# 199.0
# ./PovertyResults/POV_RDD_0/
# OOD_0  79.66 3.63 47.61 4.59
# ID_0  81.90 1.26 55.09 5.52
# TR_0  80.69 1.96 53.70 3.85
# VAL_0  77.23 3.44 39.20 6.99
# OOD_1  79.28 3.26 48.45 3.75
# ID_1  81.75 1.11 55.43 5.71
# TR_1  80.55 1.92 53.64 4.43
# VAL_1  76.91 3.38 41.07 4.25
#
#
# ' -1_ 1_ 4_ 0.0001_ 32'
# 199.0
# ./PovertyResults/POV_RDA_1/
# 199.0
# ./PovertyResults/POV_RDC_1/
# 199.0
# ./PovertyResults/POV_RDE_1/
# 199.0
# ./PovertyResults/POV_RDD_1/
# 199.0
# ./PovertyResults/POV_RD_1/
# OOD_0  79.19 3.66 46.62 3.14
# ID_0  81.81 1.94 54.46 6.37
# TR_0  80.64 1.39 51.94 3.46
# VAL_0  77.31 3.93 41.02 9.44
# OOD_1  78.65 3.62 47.44 2.74
# ID_1  82.33 1.53 55.41 5.58
# TR_1  81.42 2.02 55.16 5.60
# VAL_1  77.46 2.34 43.72 6.46
#
#
# ' -1_ 2_ 4_ 0.0001_ 32'
# 199.0
# ./PovertyResults/POV_RDE_2/
# 199.0
# ./PovertyResults/POV_RD_2/
# 199.0
# ./PovertyResults/POV_RDA_2/
# 199.0
# ./PovertyResults/POV_RDD_2/
# 199.0
# ./PovertyResults/POV_RDC_2/
# OOD_0  80.45 3.34 49.48 4.63
# ID_0  81.81 1.44 56.02 5.60
# TR_0  81.31 1.50 55.28 2.92
# VAL_0  78.05 5.09 43.02 6.44
# OOD_1  79.55 3.71 51.59 3.30
# ID_1  82.40 2.16 58.20 8.30
# TR_1  82.23 2.06 58.90 6.50
# VAL_1  78.26 2.88 44.95 4.88
#
#
# ' -1_ 3_ 4_ 0.0001_ 32'
# 199.0
# ./PovertyResults/POV_RDD_3/
# 199.0
# ./PovertyResults/POV_RD_3/
# 199.0
# ./PovertyResults/POV_RDA_3/
# 199.0
# ./PovertyResults/POV_RDC_3/
# 199.0
# ./PovertyResults/POV_RDE_3/
# OOD_0  78.97 3.10 46.23 3.38
# ID_0  80.38 3.44 51.96 7.41
# TR_0  78.93 3.55 47.20 12.16
# VAL_0  75.13 5.31 36.62 4.35
# OOD_1  78.28 3.74 48.34 2.60
# ID_1  79.64 1.88 51.21 5.81
# TR_1  78.51 3.19 48.22 5.32
# VAL_1  74.47 4.17 37.25 4.20
#
#
# ' 5_ 0_ 4_ 0.0001_ 32'
# 199.0
# ./PovertyResults/POV_RDA_4/
# 199.0
# ./PovertyResults/POV_RDE_4/
# 199.0
# ./PovertyResults/POV_RDC_4/
# 199.0
# ./PovertyResults/POV_RDD_4/
# 199.0
# ./PovertyResults/POV_RD_4/
# OOD_0  78.82 3.36 46.26 4.79
# ID_0  81.45 3.19 54.16 6.27
# TR_0  80.39 2.27 50.06 8.52
# VAL_0  77.38 4.89 39.67 9.61
# OOD_1  78.39 3.98 47.60 3.73
# ID_1  80.40 3.20 50.92 7.85
# TR_1  78.65 3.56 46.45 9.84
# VAL_1  76.61 4.21 38.20 10.31
#
#
# ' 5_ 1_ 4_ 0.0001_ 32'
# 199.0
# ./PovertyResults/POV_RDD_5/
# 199.0
# ./PovertyResults/POV_RDA_5/
# 199.0
# ./PovertyResults/POV_RDC_5/
# 199.0
# ./PovertyResults/POV_RD_5/
# 199.0
# ./PovertyResults/POV_RDE_5/
# OOD_0  78.77 3.26 45.36 4.53
# ID_0  81.91 3.40 55.82 5.53
# TR_0  80.64 2.43 51.49 9.57
# VAL_0  78.21 3.20 42.65 5.21
# OOD_1  77.93 3.83 47.54 2.94
# ID_1  79.81 2.83 50.38 5.92
# TR_1  77.92 3.14 46.20 9.60
# VAL_1  76.78 2.49 39.69 5.15
#
#
# ' 5_ 2_ 4_ 0.0001_ 32'
# 199.0
# ./PovertyResults/POV_RDE_6/
# 199.0
# ./PovertyResults/POV_RD_6/
# 199.0
# ./PovertyResults/POV_RDC_6/
# 199.0
# ./PovertyResults/POV_RDA_6/
# 199.0
# ./PovertyResults/POV_RDD_6/
# OOD_0  80.36 3.23 48.70 3.42
# ID_0  82.26 1.04 55.44 7.09
# TR_0  79.32 3.26 50.99 7.31
# VAL_0  78.91 4.30 42.59 8.28
# OOD_1  79.30 2.53 49.36 3.45
# ID_1  82.47 1.08 57.01 6.00
# TR_1  79.57 3.36 52.92 8.79
# VAL_1  78.18 3.70 42.75 5.96
#
#
# ' 5_ 3_ 4_ 0.0001_ 32'
# 199.0
# ./PovertyResults/POV_RDA_7/
# 199.0
# ./PovertyResults/POV_RDC_7/
# 199.0
# ./PovertyResults/POV_RDE_7/
# 199.0
# ./PovertyResults/POV_RD_7/
# 199.0
# ./PovertyResults/POV_RDD_7/
# OOD_0  78.72 3.43 46.35 3.71
# ID_0  80.28 3.63 50.54 8.25
# TR_0  79.36 2.78 47.29 9.66
# VAL_0  77.33 3.94 41.24 4.07
# OOD_1  78.05 3.75 48.09 2.84
# ID_1  78.14 2.29 45.54 6.17
# TR_1  76.45 2.40 40.90 6.34
# VAL_1  75.53 3.01 37.79 5.66
#
#
# ' -1_ 0_ 4_ 0.0005_ 64'
# 199.0
# ./PovertyResults/POV_RDC_8/
# 199.0
# ./PovertyResults/POV_RD_8/
# 199.0
# ./PovertyResults/POV_RDE_8/
# 199.0
# ./PovertyResults/POV_RDA_8/
# 199.0
# ./PovertyResults/POV_RDD_8/
# OOD_0  80.49 3.15 49.89 5.30
# ID_0  82.86 1.40 57.91 4.01
# TR_0  81.73 1.68 56.79 2.21
# VAL_0  78.50 3.63 45.19 6.74
# OOD_1  79.79 3.55 51.19 4.37
# ID_1  81.94 1.21 55.57 5.78
# TR_1  80.64 1.53 54.27 1.42
# VAL_1  78.33 3.24 43.79 4.61
#
#
# ' -1_ 1_ 4_ 0.0005_ 64'
# 199.0
# ./PovertyResults/POV_RDA_9/
# 199.0
# ./PovertyResults/POV_RDC_9/
# 199.0
# ./PovertyResults/POV_RDE_9/
# 199.0
# ./PovertyResults/POV_RDD_9/
# 199.0
# ./PovertyResults/POV_RD_9/
# OOD_0  80.10 3.19 48.42 4.72
# ID_0  82.09 1.78 54.85 3.58
# TR_0  80.82 1.48 52.31 5.06
# VAL_0  78.49 3.85 42.82 4.19
# OOD_1  79.75 3.59 50.38 4.97
# ID_1  83.01 0.90 57.65 3.26
# TR_1  82.62 1.52 58.87 2.35
# VAL_1  78.73 2.68 46.37 4.15
#
#
# ' -1_ 2_ 4_ 0.0005_ 64'
# 199.0
# ./PovertyResults/POV_RDC_10/
# 199.0
# ./PovertyResults/POV_RDA_10/
# 199.0
# ./PovertyResults/POV_RD_10/
# 199.0
# ./PovertyResults/POV_RDE_10/
# 199.0
# ./PovertyResults/POV_RDD_10/
# OOD_0  80.11 3.65 48.75 3.82
# ID_0  83.25 1.83 58.56 7.53
# TR_0  82.84 1.27 59.46 4.30
# VAL_0  76.46 3.75 42.81 6.31
# OOD_1  79.35 2.89 50.86 4.86
# ID_1  81.64 2.52 57.47 7.32
# TR_1  82.35 1.59 60.34 4.82
# VAL_1  74.85 3.10 39.15 4.93
#
#
# ' -1_ 3_ 4_ 0.0005_ 64'
# 199.0
# ./PovertyResults/POV_RD_11/
# 199.0
# ./PovertyResults/POV_RDA_11/
# 199.0
# ./PovertyResults/POV_RDE_11/
# 199.0
# ./PovertyResults/POV_RDC_11/
# 199.0
# ./PovertyResults/POV_RDD_11/
# OOD_0  80.01 3.50 47.73 5.23
# ID_0  81.59 2.00 54.89 3.57
# TR_0  80.36 2.24 52.50 3.89
# VAL_0  78.56 4.38 42.40 7.28
# OOD_1  78.93 3.35 48.31 4.93
# ID_1  80.74 4.16 54.94 10.02
# TR_1  80.12 4.44 54.19 9.01
# VAL_1  75.17 7.07 37.65 11.08
#
#
# ' 5_ 0_ 4_ 0.0005_ 64'
# 199.0
# ./PovertyResults/POV_RDC_12/
# 199.0
# ./PovertyResults/POV_RDA_12/
# 199.0
# ./PovertyResults/POV_RDE_12/
# 199.0
# ./PovertyResults/POV_RD_12/
# 199.0
# ./PovertyResults/POV_RDD_12/
# OOD_0  79.98 2.47 48.56 5.03
# ID_0  82.15 0.75 55.25 6.60
# TR_0  81.48 1.93 55.48 4.67
# VAL_0  78.48 3.50 44.81 7.08
# OOD_1  79.24 2.76 49.75 3.68
# ID_1  82.08 0.84 54.22 6.25
# TR_1  81.05 2.88 54.55 6.24
# VAL_1  77.46 2.35 40.37 8.81
#
#
# ' 5_ 1_ 4_ 0.0005_ 64'
# 199.0
# ./PovertyResults/POV_RD_13/
# 199.0
# ./PovertyResults/POV_RDD_13/
# 199.0
# ./PovertyResults/POV_RDC_13/
# 199.0
# ./PovertyResults/POV_RDA_13/
# 199.0
# ./PovertyResults/POV_RDE_13/
# OOD_0  80.38 2.94 48.89 4.63
# ID_0  82.19 1.21 56.55 3.41
# TR_0  81.02 1.99 54.20 3.62
# VAL_0  78.21 4.33 43.96 8.60
# OOD_1  80.10 2.70 50.04 4.09
# ID_1  82.47 1.57 57.15 4.67
# TR_1  81.66 1.52 57.14 4.75
# VAL_1  78.05 4.18 42.94 8.17
#
#
# ' 5_ 2_ 4_ 0.0005_ 64'
# 199.0
# ./PovertyResults/POV_RD_14/
# 199.0
# ./PovertyResults/POV_RDA_14/
# 199.0
# ./PovertyResults/POV_RDD_14/
# 199.0
# ./PovertyResults/POV_RDE_14/
# 199.0
# ./PovertyResults/POV_RDC_14/
# OOD_0  79.58 3.05 48.01 3.85
# ID_0  81.95 0.91 55.99 4.58
# TR_0  80.25 2.26 52.08 3.50
# VAL_0  78.38 3.54 44.23 6.08
# OOD_1  79.11 3.60 48.57 4.16
# ID_1  82.05 1.00 56.67 4.27
# TR_1  80.38 2.03 53.42 2.51
# VAL_1  75.47 4.96 42.66 9.56
#
#
# ' 5_ 3_ 4_ 0.0005_ 64'
# 199.0
# ./PovertyResults/POV_RD_15/
# 199.0
# ./PovertyResults/POV_RDD_15/
# 199.0
# ./PovertyResults/POV_RDE_15/
# 199.0
# ./PovertyResults/POV_RDA_15/
# 199.0
# ./PovertyResults/POV_RDC_15/
# OOD_0  80.45 3.07 48.26 4.30
# ID_0  82.94 1.15 56.92 5.43
# TR_0  81.89 1.94 55.13 2.71
# VAL_0  79.23 4.28 45.55 10.74
# OOD_1  79.96 2.78 49.47 3.85
# ID_1  82.81 0.89 57.13 5.43
# TR_1  81.78 1.87 56.78 4.31
# VAL_1  77.64 4.67 41.89 9.35

# %% [markdown]
# # Amazon

# %%
log_dicts = sorted(glob.glob('./AmazonResults/AMA_*/'), key= lambda x:int(re.sub('s','',x).split('_')[-1].split('/')[0]))

# %%
my_keys = ['Dataset', 'Algorithm', 'Uniform over groups', 'Distinct groups', 'N groups per batch']
my_keys += ['Batch size', 'Rd type', 'Warm start epoch', 'Control only direction', 'Only inconsistent']
my_keys += ['Without sampling', 'Lr', 'Weight decay', 'Seed', 'Dataset kwargs']

# %%
exps = {}
for log_di in log_dicts:
    #if 'RDE' not in log_di:
    #    continue
    dat_conf = parse_config_orig(log_di, my_keys)
    print(log_di, dat_conf['Lr'])
    exp_name = "{}_{}_{}_{}_{}".format(dat_conf['Warm start epoch'], dat_conf['Rd type'], 
                                 dat_conf['Lr'], dat_conf['N groups per batch'],
                                 dat_conf['Batch size'])
    if exp_name not in exps:
        exps[exp_name] = {}
    test_res = read_to_dict(log_di+'test_eval.csv')
    if 'epoch' not in test_res:
        continue
    exps[exp_name][dat_conf['Seed']] = (test_res, 
                                        read_to_dict(log_di+'val_eval.csv'), 
                                        read_to_dict(log_di+'id_test_eval.csv'),
                                        read_to_dict(log_di+'train_eval.csv'),
                                        log_di)
# Out:
# ./AmazonResults/AMA_RD_0/  5e-06
# ./AmazonResults/AMA_RD2_0/  5e-06
# ./AmazonResults/AMA_RD1_0/  5e-06
# ./AmazonResults/AMA_RD_1/  5e-06
# ./AmazonResults/AMA_RD1_1/  5e-06
# ./AmazonResults/AMA_RD2_1/  5e-06
# ./AmazonResults/AMA_RD1_2/  5e-06
# ./AmazonResults/AMA_RD_2/  5e-06
# ./AmazonResults/AMA_RD2_2/  5e-06
# ./AmazonResults/AMA_RD_3/  5e-06
# ./AmazonResults/AMA_RD1_3/  5e-06
# ./AmazonResults/AMA_RD2_3/  5e-06
# ./AmazonResults/AMA_RD_4/  5e-06
# ./AmazonResults/AMA_RD1_4/  5e-06
# ./AmazonResults/AMA_RD2_4/  5e-06
# ./AmazonResults/AMA_RD1_5/  5e-06
# ./AmazonResults/AMA_RD_5/  5e-06
# ./AmazonResults/AMA_RD2_5/  5e-06
# ./AmazonResults/AMA_RD2_6/  5e-06
# ./AmazonResults/AMA_RD1_6/  5e-06
# ./AmazonResults/AMA_RD_6/  5e-06
# ./AmazonResults/AMA_RD_7/  5e-06
# ./AmazonResults/AMA_RD2_7/  5e-06
# ./AmazonResults/AMA_RD1_7/  5e-06
# ./AmazonResults/AMA_RD2_8/  1e-05
# ./AmazonResults/AMA_RD1_8/  1e-05
# ./AmazonResults/AMA_RD_8/  1e-05
# ./AmazonResults/AMA_RD_9/  1e-05
# ./AmazonResults/AMA_RD2_9/  1e-05
# ./AmazonResults/AMA_RD1_9/  1e-05
# ./AmazonResults/AMA_RD1_10/  1e-05
# ./AmazonResults/AMA_RD2_10/  1e-05
# ./AmazonResults/AMA_RD_10/  1e-05
# ./AmazonResults/AMA_RD1_11/  1e-05
# ./AmazonResults/AMA_RD2_11/  1e-05
# ./AmazonResults/AMA_RD_11/  1e-05
# ./AmazonResults/AMA_RD1_12/  1e-05
# ./AmazonResults/AMA_RD2_12/  1e-05
# ./AmazonResults/AMA_RD_12/  1e-05
# ./AmazonResults/AMA_RD2_13/  1e-05
# ./AmazonResults/AMA_RD1_13/  1e-05
# ./AmazonResults/AMA_RD_13/  1e-05
# ./AmazonResults/AMA_RD2_14/  1e-05
# ./AmazonResults/AMA_RD_14/  1e-05
# ./AmazonResults/AMA_RD1_14/  1e-05
# ./AmazonResults/AMA_RD1_15/  1e-05
# ./AmazonResults/AMA_RD_15/  1e-05
# ./AmazonResults/AMA_RD2_15/  1e-05
# ./AmazonResults/AMA_RD_16/  1e-05
# ./AmazonResults/AMA_RD1_16/  1e-05
# ./AmazonResults/AMA_RD2_16/  1e-05
# ./AmazonResults/AMA_RD1_17/  1e-05
# ./AmazonResults/AMA_RD_17/  1e-05
# ./AmazonResults/AMA_RD2_17/  1e-05
# ./AmazonResults/AMA_RD_18/  1e-05
# ./AmazonResults/AMA_RD2_18/  1e-05
# ./AmazonResults/AMA_RD1_18/  1e-05
# ./AmazonResults/AMA_RD1_19/  1e-05
# ./AmazonResults/AMA_RD2_19/  1e-05
# ./AmazonResults/AMA_RD_19/  1e-05
# ./AmazonResults/AMA_RD_20/  1e-05
# ./AmazonResults/AMA_RD1_20/  1e-05
# ./AmazonResults/AMA_RD2_20/  1e-05
# ./AmazonResults/AMA_RD1_21/  1e-05
# ./AmazonResults/AMA_RD_21/  1e-05
# ./AmazonResults/AMA_RD2_21/  1e-05
# ./AmazonResults/AMA_RD2_22/  1e-05
# ./AmazonResults/AMA_RD1_22/  1e-05
# ./AmazonResults/AMA_RD_22/  1e-05
# ./AmazonResults/AMA_RD_23/  1e-05
# ./AmazonResults/AMA_RD1_23/  1e-05
# ./AmazonResults/AMA_RD2_23/  1e-05
# ./AmazonResults/AMA_RD2_24/  1e-05
# ./AmazonResults/AMA_RD_24/  1e-05
# ./AmazonResults/AMA_RD1_24/  1e-05
# ./AmazonResults/AMA_RD_25/  1e-05
# ./AmazonResults/AMA_RD1_25/  1e-05
# ./AmazonResults/AMA_RD2_25/  1e-05
# ./AmazonResults/AMA_RD2_26/  1e-05
# ./AmazonResults/AMA_RD_26/  1e-05
# ./AmazonResults/AMA_RD1_26/  1e-05
# ./AmazonResults/AMA_RD1_27/  1e-05
# ./AmazonResults/AMA_RD2_27/  1e-05
# ./AmazonResults/AMA_RD1_28/  1e-05
# ./AmazonResults/AMA_RD2_28/  1e-05
# ./AmazonResults/AMA_RD_28/  1e-05
# ./AmazonResults/AMA_RD2_29/  1e-05
# ./AmazonResults/AMA_RD1_29/  1e-05
# ./AmazonResults/AMA_RD_29/  1e-05
# ./AmazonResults/AMA_RD2_30/  1e-05
# ./AmazonResults/AMA_RD1_30/  1e-05
# ./AmazonResults/AMA_RD_30/  1e-05
# ./AmazonResults/AMA_RD1_31/  1e-05
# ./AmazonResults/AMA_RD_31/  1e-05
# ./AmazonResults/AMA_RD2_31/  1e-05
# ./AmazonResults/AMA_RD2_32/  1e-05
# ./AmazonResults/AMA_RD1_32/  1e-05
# ./AmazonResults/AMA_RD_32/  1e-05
# ./AmazonResults/AMA_RD1_33/  1e-05
# ./AmazonResults/AMA_RD2_33/  1e-05
# ./AmazonResults/AMA_RD_33/  1e-05
# ./AmazonResults/AMA_RD2_34/  1e-05
# ./AmazonResults/AMA_RD1_34/  1e-05
# ./AmazonResults/AMA_RD_34/  1e-05
# ./AmazonResults/AMA_RD1_35/  1e-05
# ./AmazonResults/AMA_RD_35/  1e-05
# ./AmazonResults/AMA_RD2_35/  1e-05
# ./AmazonResults/AMA_RD_36/  1e-05
# ./AmazonResults/AMA_RD1_36/  1e-05
# ./AmazonResults/AMA_RD2_36/  1e-05
# ./AmazonResults/AMA_RD1_37/  1e-05
# ./AmazonResults/AMA_RD2_37/  1e-05
# ./AmazonResults/AMA_RD_37/  1e-05
# ./AmazonResults/AMA_RD_38/  1e-05
# ./AmazonResults/AMA_RD2_38/  1e-05
# ./AmazonResults/AMA_RD1_38/  1e-05
# ./AmazonResults/AMA_RD1_39/  1e-05
# ./AmazonResults/AMA_RD_39/  1e-05
# ./AmazonResults/AMA_RD2_39/  1e-05
# ./AmazonResults/AMA_RD_40/  1e-05
# ./AmazonResults/AMA_RD2_40/  1e-05
# ./AmazonResults/AMA_RD1_40/  1e-05
# ./AmazonResults/AMA_RD1_41/  1e-05
# ./AmazonResults/AMA_RD2_41/  1e-05
# ./AmazonResults/AMA_RD_41/  1e-05
# ./AmazonResults/AMA_RD_42/  1e-05
# ./AmazonResults/AMA_RD2_42/  1e-05
# ./AmazonResults/AMA_RD1_42/  1e-05
# ./AmazonResults/AMA_RD2_43/  1e-05
# ./AmazonResults/AMA_RD1_43/  1e-05
# ./AmazonResults/AMA_RD_43/  1e-05
# ./AmazonResults/AMA_RD_44/  1e-05
# ./AmazonResults/AMA_RD2_44/  1e-05
# ./AmazonResults/AMA_RD1_44/  1e-05
# ./AmazonResults/AMA_RD1_45/  1e-05
# ./AmazonResults/AMA_RD_45/  1e-05
# ./AmazonResults/AMA_RD2_45/  1e-05
# ./AmazonResults/AMA_RD_46/  1e-05
# ./AmazonResults/AMA_RD1_46/  1e-05
# ./AmazonResults/AMA_RD2_46/  1e-05
# ./AmazonResults/AMA_RD2_47/  1e-05
# ./AmazonResults/AMA_RD_47/  1e-05
# ./AmazonResults/AMA_RD1_47/  1e-05

# %%
for exp_id in exps:
    print("'{}'".format(exp_id))
    breakl = False
    for kk in exps[exp_id]:
        if 'epoch' not in exps[exp_id][kk][0]:
            breakl = True
            continue
        print(np.max(exps[exp_id][kk][0]['epoch']))
        print(exps[exp_id][kk][4])
    #if breakl:
    #    continue
    resO = collect_results(exps[exp_id], ('acc_avg', '10th_percentile_acc'), 0, None)

    for alg in resO:
        res_test_str = "OOD_{} ".format(alg) +print_row(resO[alg]['test'], ('acc_avg', '10th_percentile_acc'))
        res_id_t_str = "ID_{} ".format(alg) +print_row(resO[alg]['id_test'], ('acc_avg', '10th_percentile_acc'))
        res_train_str = "TR_{} ".format(alg) +print_row(resO[alg]['train'], ('acc_avg', '10th_percentile_acc'))
        res_val_str = "VAL_{} ".format(alg) +print_row(resO[alg]['val'], ('acc_avg', '10th_percentile_acc'))

        print(res_test_str)
        print(res_id_t_str)
        #print(res_train_str)
        #print(res_val_str)
    print('\n')
# Out:
# ' -1_ 0_ 5e-06_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD_0/
# 1.0
# ./AmazonResults/AMA_RD2_0/
# 2.0
# ./AmazonResults/AMA_RD1_0/
# OOD_0  70.26 0.11 52.89 0.63
# ID_0  72.29 0.06 53.78 0.63
# OOD_1  70.13 0.27 52.89 0.63
# ID_1  71.95 0.42 53.33 1.09
#
#
# ' -1_ 1_ 5e-06_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD_1/
# 2.0
# ./AmazonResults/AMA_RD1_1/
# 1.0
# ./AmazonResults/AMA_RD2_1/
# OOD_0  71.29 0.17 53.33 1.09
# ID_0  73.55 0.14 56.00 0.00
# OOD_1  71.05 0.34 53.78 0.63
# ID_1  73.04 0.47 55.56 0.63
#
#
# ' -1_ 2_ 5e-06_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD1_2/
# 2.0
# ./AmazonResults/AMA_RD_2/
# 2.0
# ./AmazonResults/AMA_RD2_2/
# OOD_0  70.71 0.12 53.02 0.44
# ID_0  73.09 0.13 55.11 0.63
# OOD_1  70.35 0.27 53.02 0.44
# ID_1  72.61 0.36 55.56 0.63
#
#
# ' -1_ 3_ 5e-06_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD_3/
# 2.0
# ./AmazonResults/AMA_RD1_3/
# 2.0
# ./AmazonResults/AMA_RD2_3/
# OOD_0  71.18 0.09 52.00 1.09
# ID_0  73.07 0.05 53.78 0.63
# OOD_1  70.75 0.31 53.78 0.63
# ID_1  72.98 0.30 55.56 0.63
#
#
# ' 1_ 0_ 5e-06_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD_4/
# 2.0
# ./AmazonResults/AMA_RD1_4/
# 2.0
# ./AmazonResults/AMA_RD2_4/
# OOD_0  71.64 0.07 53.91 0.56
# ID_0  73.87 0.13 55.78 0.31
# OOD_1  71.55 0.04 54.22 0.63
# ID_1  73.94 0.10 55.33 0.54
#
#
# ' 1_ 1_ 5e-06_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD1_5/
# 2.0
# ./AmazonResults/AMA_RD_5/
# 2.0
# ./AmazonResults/AMA_RD2_5/
# OOD_0  71.74 0.11 53.78 0.63
# ID_0  74.11 0.09 55.78 0.31
# OOD_1  71.57 0.05 53.91 0.56
# ID_1  73.85 0.11 55.78 0.31
#
#
# ' 1_ 2_ 5e-06_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD2_6/
# 2.0
# ./AmazonResults/AMA_RD1_6/
# 2.0
# ./AmazonResults/AMA_RD_6/
# OOD_0  71.61 0.03 54.36 0.44
# ID_0  73.87 0.14 55.78 0.31
# OOD_1  71.53 0.10 54.67 0.00
# ID_1  73.92 0.11 56.22 0.83
#
#
# ' 1_ 3_ 5e-06_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD_7/
# 2.0
# ./AmazonResults/AMA_RD2_7/
# 2.0
# ./AmazonResults/AMA_RD1_7/
# OOD_0  71.64 0.07 53.91 0.56
# ID_0  73.89 0.16 55.78 0.31
# OOD_1  71.56 0.05 54.22 0.63
# ID_1  73.95 0.11 55.78 0.31
#
#
# ' -1_ 0_ 1e-05_ 2_ 8'
# 1.0
# ./AmazonResults/AMA_RD2_8/
# 2.0
# ./AmazonResults/AMA_RD1_8/
# 2.0
# ./AmazonResults/AMA_RD_8/
# OOD_0  70.29 0.36 52.89 0.63
# ID_0  72.36 0.54 53.56 0.31
# OOD_1  70.29 0.36 52.89 0.63
# ID_1  72.36 0.54 53.56 0.31
#
#
# ' -1_ 1_ 1e-05_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD_9/
# 0.0
# ./AmazonResults/AMA_RD2_9/
# 2.0
# ./AmazonResults/AMA_RD1_9/
# OOD_0  71.19 0.07 53.02 1.49
# ID_0  73.27 0.26 55.11 0.63
# OOD_1  70.93 0.18 53.78 0.63
# ID_1  73.06 0.18 55.56 0.63
#
#
# ' -1_ 2_ 1e-05_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD1_10/
# 2.0
# ./AmazonResults/AMA_RD2_10/
# 2.0
# ./AmazonResults/AMA_RD_10/
# OOD_0  70.52 0.23 52.00 0.00
# ID_0  72.89 0.05 54.67 0.00
# OOD_1  70.05 0.29 52.44 0.63
# ID_1  72.29 0.52 54.22 0.63
#
#
# ' -1_ 3_ 1e-05_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD1_11/
# 2.0
# ./AmazonResults/AMA_RD2_11/
# 2.0
# ./AmazonResults/AMA_RD_11/
# OOD_0  71.20 0.17 52.44 1.26
# ID_0  73.27 0.22 54.89 0.83
# OOD_1  70.97 0.19 53.78 0.63
# ID_1  73.27 0.05 56.00 0.00
#
#
# ' 1_ 0_ 1e-05_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD1_12/
# 2.0
# ./AmazonResults/AMA_RD2_12/
# 2.0
# ./AmazonResults/AMA_RD_12/
# OOD_0  71.48 0.01 53.33 0.00
# ID_0  73.86 0.13 55.78 0.31
# OOD_1  71.35 0.19 53.78 0.63
# ID_1  73.77 0.16 56.00 0.00
#
#
# ' 1_ 1_ 1e-05_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD2_13/
# 2.0
# ./AmazonResults/AMA_RD1_13/
# 2.0
# ./AmazonResults/AMA_RD_13/
# OOD_0  71.48 0.01 53.33 0.00
# ID_0  73.86 0.13 55.78 0.31
# OOD_1  71.44 0.05 53.78 0.63
# ID_1  73.90 0.15 56.00 0.00
#
#
# ' 1_ 2_ 1e-05_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD2_14/
# 2.0
# ./AmazonResults/AMA_RD_14/
# 2.0
# ./AmazonResults/AMA_RD1_14/
# OOD_0  71.48 0.01 53.33 0.00
# ID_0  73.86 0.13 55.78 0.31
# OOD_1  71.20 0.39 53.78 0.63
# ID_1  73.63 0.33 56.00 0.00
#
#
# ' 1_ 3_ 1e-05_ 2_ 8'
# 2.0
# ./AmazonResults/AMA_RD1_15/
# 2.0
# ./AmazonResults/AMA_RD_15/
# 2.0
# ./AmazonResults/AMA_RD2_15/
# OOD_0  71.48 0.01 53.33 0.00
# ID_0  73.86 0.13 55.78 0.31
# OOD_1  71.37 0.15 53.78 0.63
# ID_1  73.83 0.13 56.00 0.00
#
#
# ' -1_ 0_ 1e-05_ 2_ 16'
# 2.0
# ./AmazonResults/AMA_RD_16/
# 2.0
# ./AmazonResults/AMA_RD1_16/
# 2.0
# ./AmazonResults/AMA_RD2_16/
# OOD_0  70.97 0.24 52.44 1.26
# ID_0  72.84 0.21 54.89 1.37
# OOD_1  70.74 0.28 53.47 0.19
# ID_1  72.55 0.51 54.67 1.09
#
#
# ' -1_ 1_ 1e-05_ 2_ 16'
# 2.0
# ./AmazonResults/AMA_RD1_17/
# 2.0
# ./AmazonResults/AMA_RD_17/
# 2.0
# ./AmazonResults/AMA_RD2_17/
# OOD_0  71.83 0.04 53.78 1.26
# ID_0  74.22 0.05 55.56 0.63
# OOD_1  71.76 0.07 54.22 0.63
# ID_1  74.18 0.11 56.00 0.00
#
#
# ' -1_ 2_ 1e-05_ 2_ 16'
# 2.0
# ./AmazonResults/AMA_RD_18/
# 2.0
# ./AmazonResults/AMA_RD2_18/
# 2.0
# ./AmazonResults/AMA_RD1_18/
# OOD_0  70.90 0.29 52.44 1.26
# ID_0  73.09 0.08 54.67 1.09
# OOD_1  70.46 0.22 53.33 0.00
# ID_1  72.69 0.31 54.67 1.09
#
#
# ' -1_ 3_ 1e-05_ 2_ 16'
# 2.0
# ./AmazonResults/AMA_RD1_19/
# 2.0
# ./AmazonResults/AMA_RD2_19/
# 2.0
# ./AmazonResults/AMA_RD_19/
# OOD_0  71.73 0.05 53.33 1.09
# ID_0  74.01 0.10 55.11 1.26
# OOD_1  71.60 0.05 54.22 0.63
# ID_1  73.94 0.02 56.00 0.00
#
#
# ' 1_ 0_ 1e-05_ 2_ 16'
# 2.0
# ./AmazonResults/AMA_RD_20/
# 2.0
# ./AmazonResults/AMA_RD1_20/
# 2.0
# ./AmazonResults/AMA_RD2_20/
# OOD_0  71.74 0.07 53.78 0.63
# ID_0  74.23 0.03 55.56 0.63
# OOD_1  71.72 0.09 54.22 0.63
# ID_1  74.18 0.11 55.56 0.63
#
#
# ' 1_ 1_ 1e-05_ 2_ 16'
# 2.0
# ./AmazonResults/AMA_RD1_21/
# 2.0
# ./AmazonResults/AMA_RD_21/
# 2.0
# ./AmazonResults/AMA_RD2_21/
# OOD_0  71.84 0.08 54.22 0.63
# ID_0  74.23 0.05 55.56 0.63
# OOD_1  71.77 0.15 54.22 0.63
# ID_1  74.15 0.10 55.56 0.63
#
#
# ' 1_ 2_ 1e-05_ 2_ 16'
# 2.0
# ./AmazonResults/AMA_RD2_22/
# 2.0
# ./AmazonResults/AMA_RD1_22/
# 2.0
# ./AmazonResults/AMA_RD_22/
# OOD_0  71.66 0.08 53.78 0.63
# ID_0  74.06 0.16 55.56 0.63
# OOD_1  71.62 0.11 54.22 0.63
# ID_1  74.10 0.12 55.56 0.63
#
#
# ' 1_ 3_ 1e-05_ 2_ 16'
# 2.0
# ./AmazonResults/AMA_RD_23/
# 2.0
# ./AmazonResults/AMA_RD1_23/
# 2.0
# ./AmazonResults/AMA_RD2_23/
# OOD_0  71.76 0.07 53.78 0.63
# ID_0  74.24 0.02 55.78 0.83
# OOD_1  71.74 0.10 54.22 0.63
# ID_1  74.17 0.10 55.56 0.63
#
#
# ' -1_ 0_ 1e-05_ 4_ 16'
# 2.0
# ./AmazonResults/AMA_RD2_24/
# 2.0
# ./AmazonResults/AMA_RD_24/
# 2.0
# ./AmazonResults/AMA_RD1_24/
# OOD_0  70.52 0.24 52.44 0.63
# ID_0  72.60 0.17 54.22 0.63
# OOD_1  69.93 0.25 52.44 0.63
# ID_1  71.97 0.34 53.78 0.63
#
#
# ' -1_ 1_ 1e-05_ 4_ 16'
# 2.0
# ./AmazonResults/AMA_RD_25/
# 2.0
# ./AmazonResults/AMA_RD1_25/
# 0.0
# ./AmazonResults/AMA_RD2_25/
# OOD_0  70.32 1.18 52.89 0.63
# ID_0  72.24 1.42 54.22 1.66
# OOD_1  70.04 1.07 52.89 0.63
# ID_1  71.95 1.28 53.78 1.26
#
#
# ' -1_ 2_ 1e-05_ 4_ 16'
# 0.0
# ./AmazonResults/AMA_RD2_26/
# 2.0
# ./AmazonResults/AMA_RD_26/
# 2.0
# ./AmazonResults/AMA_RD1_26/
# OOD_0  68.77 1.73 51.11 1.66
# ID_0  70.94 1.86 52.89 2.51
# OOD_1  68.61 1.64 52.00 1.89
# ID_1  70.74 1.79 52.89 2.51
#
#
# ' -1_ 3_ 1e-05_ 4_ 16'
# 2.0
# ./AmazonResults/AMA_RD1_27/
# 0.0
# ./AmazonResults/AMA_RD2_27/
# OOD_0  70.14 1.11 52.00 0.00
# ID_0  71.98 1.11 53.33 0.00
# OOD_1  70.12 1.09 52.87 0.87
# ID_1  72.06 1.20 54.67 1.33
#
#
# ' 1_ 0_ 1e-05_ 4_ 16'
# 2.0
# ./AmazonResults/AMA_RD1_28/
# 2.0
# ./AmazonResults/AMA_RD2_28/
# 2.0
# ./AmazonResults/AMA_RD_28/
# OOD_0  71.57 0.27 53.73 0.00
# ID_0  73.99 0.22 56.00 0.00
# OOD_1  71.37 0.24 54.36 0.44
# ID_1  73.92 0.18 56.67 0.54
#
#
# ' 1_ 1_ 1e-05_ 4_ 16'
# 2.0
# ./AmazonResults/AMA_RD2_29/
# 2.0
# ./AmazonResults/AMA_RD1_29/
# 2.0
# ./AmazonResults/AMA_RD_29/
# OOD_0  71.64 0.19 53.33 0.00
# ID_0  74.19 0.10 55.78 0.31
# OOD_1  70.59 0.72 53.78 0.63
# ID_1  72.97 1.01 56.22 0.31
#
#
# ' 1_ 2_ 1e-05_ 4_ 16'
# 2.0
# ./AmazonResults/AMA_RD2_30/
# 2.0
# ./AmazonResults/AMA_RD1_30/
# 2.0
# ./AmazonResults/AMA_RD_30/
# OOD_0  71.57 0.23 53.47 0.93
# ID_0  73.85 0.26 55.56 0.63
# OOD_1  70.61 0.74 53.78 0.63
# ID_1  72.96 1.00 56.67 0.54
#
#
# ' 1_ 3_ 1e-05_ 4_ 16'
# 2.0
# ./AmazonResults/AMA_RD1_31/
# 2.0
# ./AmazonResults/AMA_RD_31/
# 2.0
# ./AmazonResults/AMA_RD2_31/
# OOD_0  71.57 0.24 53.78 0.63
# ID_0  74.03 0.18 56.00 0.00
# OOD_1  71.29 0.27 54.22 0.63
# ID_1  73.78 0.13 56.22 0.31
#
#
# ' -1_ 0_ 1e-05_ 4_ 32'
# 2.0
# ./AmazonResults/AMA_RD2_32/
# 1.0
# ./AmazonResults/AMA_RD1_32/
# 2.0
# ./AmazonResults/AMA_RD_32/
# OOD_0  70.71 0.09 52.58 0.56
# ID_0  72.63 0.10 54.67 0.00
# OOD_1  70.14 0.52 53.33 0.00
# ID_1  71.89 0.83 54.22 0.63
#
#
# ' -1_ 1_ 1e-05_ 4_ 32'
# 1.0
# ./AmazonResults/AMA_RD1_33/
# 2.0
# ./AmazonResults/AMA_RD2_33/
# 2.0
# ./AmazonResults/AMA_RD_33/
# OOD_0  71.73 0.10 52.89 0.63
# ID_0  73.69 0.03 55.56 0.63
# OOD_1  70.57 0.28 53.33 0.00
# ID_1  72.18 0.32 54.67 0.00
#
#
# ' -1_ 2_ 1e-05_ 4_ 32'
# 2.0
# ./AmazonResults/AMA_RD2_34/
# 2.0
# ./AmazonResults/AMA_RD1_34/
# 1.0
# ./AmazonResults/AMA_RD_34/
# OOD_0  70.97 0.14 53.33 0.00
# ID_0  73.34 0.11 56.00 0.00
# OOD_1  70.55 0.31 53.33 0.00
# ID_1  72.45 0.55 55.56 0.63
#
#
# ' -1_ 3_ 1e-05_ 4_ 32'
# 2.0
# ./AmazonResults/AMA_RD1_35/
# 1.0
# ./AmazonResults/AMA_RD_35/
# 2.0
# ./AmazonResults/AMA_RD2_35/
# OOD_0  71.69 0.04 52.89 0.63
# ID_0  73.65 0.14 55.33 0.54
# OOD_1  70.95 0.59 52.89 0.63
# ID_1  72.77 0.68 54.67 0.00
#
#
# ' 1_ 0_ 1e-05_ 4_ 32'
# 2.0
# ./AmazonResults/AMA_RD_36/
# 2.0
# ./AmazonResults/AMA_RD1_36/
# 2.0
# ./AmazonResults/AMA_RD2_36/
# OOD_0  71.88 0.02 53.16 0.82
# ID_0  74.06 0.04 55.56 0.63
# OOD_1  71.61 0.40 53.60 0.19
# ID_1  73.75 0.46 55.78 0.31
#
#
# ' 1_ 1_ 1e-05_ 4_ 32'
# 2.0
# ./AmazonResults/AMA_RD1_37/
# 2.0
# ./AmazonResults/AMA_RD2_37/
# 2.0
# ./AmazonResults/AMA_RD_37/
# OOD_0  71.90 0.04 53.33 1.09
# ID_0  74.13 0.15 55.56 0.63
# OOD_1  71.34 0.44 53.78 0.63
# ID_1  73.30 0.53 55.56 0.31
#
#
# ' 1_ 2_ 1e-05_ 4_ 32'
# 2.0
# ./AmazonResults/AMA_RD_38/
# 2.0
# ./AmazonResults/AMA_RD2_38/
# 2.0
# ./AmazonResults/AMA_RD1_38/
# OOD_0  71.80 0.07 53.33 0.00
# ID_0  74.00 0.09 56.44 0.63
# OOD_1  71.08 0.27 53.78 0.63
# ID_1  73.02 0.57 56.00 0.54
#
#
# ' 1_ 3_ 1e-05_ 4_ 32'
# 2.0
# ./AmazonResults/AMA_RD1_39/
# 2.0
# ./AmazonResults/AMA_RD_39/
# 2.0
# ./AmazonResults/AMA_RD2_39/
# OOD_0  71.90 0.05 52.89 0.63
# ID_0  74.06 0.06 55.56 0.63
# OOD_1  70.95 0.12 53.33 0.00
# ID_1  72.77 0.25 55.33 0.54
#
#
# ' -1_ 0_ 1e-05_ 8_ 32'
# 0.0
# ./AmazonResults/AMA_RD_40/
# 2.0
# ./AmazonResults/AMA_RD2_40/
# 1.0
# ./AmazonResults/AMA_RD1_40/
# OOD_0  71.20 0.16 52.89 0.63
# ID_0  73.18 0.32 54.44 1.13
# OOD_1  71.16 0.12 53.33 1.09
# ID_1  73.12 0.27 54.89 1.13
#
#
# ' -1_ 1_ 1e-05_ 8_ 32'
# 0.0
# ./AmazonResults/AMA_RD1_41/
# 2.0
# ./AmazonResults/AMA_RD2_41/
# 0.0
# ./AmazonResults/AMA_RD_41/
# OOD_0  71.12 0.32 52.00 1.09
# ID_0  72.88 0.54 53.11 1.13
# OOD_1  71.12 0.32 52.00 1.09
# ID_1  72.88 0.54 53.11 1.13
#
#
# ' -1_ 2_ 1e-05_ 8_ 32'
# 0.0
# ./AmazonResults/AMA_RD_42/
# 2.0
# ./AmazonResults/AMA_RD2_42/
# 0.0
# ./AmazonResults/AMA_RD1_42/
# OOD_0  70.91 0.49 52.89 1.26
# ID_0  72.95 0.59 54.67 1.09
# OOD_1  70.91 0.49 52.89 1.26
# ID_1  72.95 0.59 54.67 1.09
#
#
# ' -1_ 3_ 1e-05_ 8_ 32'
# 2.0
# ./AmazonResults/AMA_RD2_43/
# 0.0
# ./AmazonResults/AMA_RD1_43/
# 0.0
# ./AmazonResults/AMA_RD_43/
# OOD_0  71.01 0.33 51.56 1.26
# ID_0  72.83 0.57 53.33 0.94
# OOD_1  71.01 0.33 51.56 1.26
# ID_1  72.83 0.57 53.33 0.94
#
#
# ' 1_ 0_ 1e-05_ 8_ 32'
# 2.0
# ./AmazonResults/AMA_RD_44/
# 2.0
# ./AmazonResults/AMA_RD2_44/
# 2.0
# ./AmazonResults/AMA_RD1_44/
# OOD_0  71.84 0.05 53.91 0.56
# ID_0  74.20 0.05 55.56 0.63
# OOD_1  71.74 0.15 54.04 0.44
# ID_1  73.96 0.20 55.33 0.94
#
#
# ' 1_ 1_ 1e-05_ 8_ 32'
# 2.0
# ./AmazonResults/AMA_RD1_45/
# 2.0
# ./AmazonResults/AMA_RD_45/
# 2.0
# ./AmazonResults/AMA_RD2_45/
# OOD_0  71.87 0.04 53.91 0.56
# ID_0  74.16 0.05 56.00 0.00
# OOD_1  71.78 0.17 54.04 0.44
# ID_1  74.07 0.16 56.22 0.31
#
#
# ' 1_ 2_ 1e-05_ 8_ 32'
# 2.0
# ./AmazonResults/AMA_RD_46/
# 2.0
# ./AmazonResults/AMA_RD1_46/
# 2.0
# ./AmazonResults/AMA_RD2_46/
# OOD_0  71.82 0.07 53.33 0.00
# ID_0  74.16 0.04 55.78 0.31
# OOD_1  71.74 0.15 53.60 0.19
# ID_1  73.95 0.19 55.78 0.83
#
#
# ' 1_ 3_ 1e-05_ 8_ 32'
# 2.0
# ./AmazonResults/AMA_RD2_47/
# 2.0
# ./AmazonResults/AMA_RD_47/
# 2.0
# ./AmazonResults/AMA_RD1_47/
# OOD_0  71.81 0.10 54.22 0.63
# ID_0  74.22 0.04 55.78 0.31
# OOD_1  71.76 0.18 54.67 0.00
# ID_1  74.15 0.14 55.78 0.31
